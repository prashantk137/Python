# %%
import pandas as pd

# %%
df=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1=df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age','GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.to_csv('NBA.csv')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1E4D-DCE3
#
#  Directory of C:\Users\PRASHANT KUMAR
#
# 18-04-2022  13:06    <DIR>          .
# 16-01-2022  13:18    <DIR>          ..
# 15-12-2019  12:13    <DIR>          .anaconda
# 14-02-2020  11:35    <DIR>          .android
# 17-01-2020  11:04    <DIR>          .AndroidStudio3.5
# 21-07-2020  17:20               145 .appletviewer
# 25-03-2022  10:52             1,010 .bash_history
# 29-06-2021  14:36    <DIR>          .cache
# 25-02-2022  09:33    <DIR>          .conda
# 15-10-2020  13:05                43 .condarc
# 08-02-2020  15:55    <DIR>          .config
# 28-11-2021  13:34    <DIR>          .continuum
# 14-06-2020  13:49    <DIR>          .dotnet
# 11-03-2020  18:33    <DIR>          .eclipse
# 17-01-2020  11:55                16 .emulator_console_auth_token
# 25-03-2022  09:44               214 .gitconfig
# 25-03-2022  09:04            12,288 .gitconfig.swp
# 17-01-2020  11:55    <DIR>          .gradle
# 07-02-2020  16:05    <DIR>          .idlerc
# 18-04-2022  12:33    <DIR>          .ipynb_checkpoints
# 15-12-2019  01:37    <DIR>          .ipython
# 19-12-2021  11:28    <DIR>          .jupyter
# 28-07-2020  20:31    <DIR>          .m2
# 14-12-2019  15:17    <DIR>          .nbi
# 29-06-2021  14:50    <DIR>          .p2
# 02-12-2021  09:25    <DIR>          .spyder-py3
# 11-03-2020  18:33    <DIR>          .tooling
# 25-03-2022  09:05               762 .viminfo
# 25-12-2021  16:01    <DIR>          .VirtualBox
# 14-12-2019  18:39    <DIR>          .vscode
# 13-03-2022  15:36    <DIR>          __pycache__
# 26-12-2021  09:38             3,504 21st dec(for,while).ipynb
# 24-08-2021  15:06    <DIR>          3D Objects
# 23-03-2022  17:10             7,566 Abstraction.ipynb
# 14-02-2020  12:38    <DIR>          AndroidStudioProjects
# 28-01-2022  11:39               149 arithmatic.py
# 04-04-2022  09:01            51,867 car.data
# 07-04-2022  16:34           628,633 carbon_nanotubes.csv
# 15-04-2022  16:33             1,631 Casandra.ipynb
# 21-12-2021  12:45             7,578 conditional statement.ipynb
# 16-01-2022  15:37    <DIR>          Contacts
# 17-04-2022  13:02    <DIR>          Desktop
# 07-03-2022  18:09    <DIR>          Documents
# 17-04-2022  12:37    <DIR>          Downloads
# 29-06-2021  14:05    <DIR>          eclipse
# 29-06-2021  12:21    <DIR>          eclipse-workspace
# 02-02-2022  20:52            33,366 Exception Handling.ipynb
# 16-01-2022  15:37    <DIR>          Favorites
# 24-12-2021  14:54            13,457 for, while,lambda.ipynb
# 11-01-2022  16:25            34,720 function with argument,iterable,iterator.ipynb
# 29-12-2021  12:40            14,911 Function(23th Dec).ipynb
# 18-01-2022  16:02            67,764 generator,file operation.ipynb
# 01-04-2022  11:24            11,903 glass.data
# 16-10-2021  14:43    <DIR>          IBA_IOAPDATA
# 14-04-2022  08:13             8,192 ineuron.db
# 21-03-2022  15:51            51,131 Inheritance.ipynb
# 14-04-2022  13:35            12,288 joindb.db
# 16-01-2022  15:37    <DIR>          Links
# 16-04-2022  14:30           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 16-04-2022  14:30           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 16-04-2022  14:30            95,503 LUSID Excel - Manage instruments with economic definitions.xlsx
# 16-04-2022  14:30            84,319 LUSID Excel - Manage Orders.xlsx
# 16-04-2022  14:30           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 16-04-2022  14:30           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 16-04-2022  14:30           136,632 LUSID Excel - Setting up your market data.xlsx
# 28-01-2022  12:37             8,176 modules and package.ipynb
# 07-04-2022  16:41            37,174 Mongodb.ipynb
# 16-01-2022  15:37    <DIR>          Music
# 13-03-2022  15:35               635 mydict.py
# 18-04-2022  13:38            81,552 NBA.csv
# 27-01-2022  11:26    <DIR>          OneDrive
# 13-03-2022  16:07             1,641 Oops(Part1).ipynb
# 13-03-2022  20:42            17,056 oops.ipynb
# 14-12-2019  15:55    <DIR>          Oracle
# 18-04-2022  13:06            60,547 Pandas(2).ipynb
# 18-04-2022  12:32           206,347 Pandas.ipynb
# 14-04-2022  08:11             8,192 person.db
# 16-01-2022  15:37    <DIR>          Pictures
# 23-03-2022  17:10             9,704 polymorphism.ipynb
# 09-03-2022  09:11    <DIR>          PycharmProjects
# 25-03-2022  09:14    <DIR>          Python
# 19-01-2022  16:27            37,898 Questions.ipynb
# 16-04-2022  13:53               244 sample_test.csv
# 16-01-2022  15:37    <DIR>          Saved Games
# 16-01-2022  15:37    <DIR>          Searches
# 14-12-2019  18:13    <DIR>          source
# 01-04-2022  13:05           124,230 sql connection(part-1).ipynb
# 04-04-2022  13:47           492,986 sql(part-2).ipynb
# 14-04-2022  16:22            64,198 SqlLite,map,reduce,filter,zip.ipynb
# 16-11-2020  19:41       114,273,560 Teams_windows_x64.exe
# 25-01-2022  21:15               179 test.log
# 18-01-2022  14:34                 0 test.txt
# 16-03-2022  21:25                22 test1.txt
# 25-01-2022  21:34               719 test2.log
# 18-01-2022  14:40                21 test2.txt
# 28-01-2022  11:31               154 test22.py
# 25-01-2022  21:38                 0 test3.log
# 18-01-2022  14:30                 0 text.txt
# 28-11-2021  09:11    <DIR>          Tracing
# 30-03-2022  15:47             1,858 Untitled.ipynb
# 04-12-2021  14:23            14,021 Untitled1.ipynb
# 11-01-2022  16:09            34,720 Untitled15.ipynb
# 12-01-2022  14:08             4,789 Untitled16.ipynb
# 05-12-2021  13:48            15,628 Untitled2.ipynb
# 18-12-2021  15:27            17,346 Untitled3.ipynb
# 22-01-2022  13:11            12,826 Untitled4.ipynb
# 19-12-2021  12:54             7,580 Untitled5.ipynb
# 21-12-2021  12:33             3,794 Untitled6.ipynb
# 23-03-2022  10:42                72 Untitled7.ipynb
# 23-03-2022  14:29                72 Untitled8.ipynb
# 16-01-2022  15:37    <DIR>          Videos
# 16-11-2020  19:16       102,233,600 webexapp.msi
# 27-12-2021  10:39            10,289 while.ipynb
#               67 File(s)    219,706,249 bytes
#               46 Dir(s)  118,833,037,312 bytes free

# %%
df1.to_csv('NBA.csv',index=False)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1E4D-DCE3
#
#  Directory of C:\Users\PRASHANT KUMAR
#
# 18-04-2022  13:49    <DIR>          .
# 16-01-2022  13:18    <DIR>          ..
# 15-12-2019  12:13    <DIR>          .anaconda
# 14-02-2020  11:35    <DIR>          .android
# 17-01-2020  11:04    <DIR>          .AndroidStudio3.5
# 21-07-2020  17:20               145 .appletviewer
# 25-03-2022  10:52             1,010 .bash_history
# 29-06-2021  14:36    <DIR>          .cache
# 25-02-2022  09:33    <DIR>          .conda
# 15-10-2020  13:05                43 .condarc
# 08-02-2020  15:55    <DIR>          .config
# 28-11-2021  13:34    <DIR>          .continuum
# 14-06-2020  13:49    <DIR>          .dotnet
# 11-03-2020  18:33    <DIR>          .eclipse
# 17-01-2020  11:55                16 .emulator_console_auth_token
# 25-03-2022  09:44               214 .gitconfig
# 25-03-2022  09:04            12,288 .gitconfig.swp
# 17-01-2020  11:55    <DIR>          .gradle
# 07-02-2020  16:05    <DIR>          .idlerc
# 18-04-2022  12:33    <DIR>          .ipynb_checkpoints
# 15-12-2019  01:37    <DIR>          .ipython
# 19-12-2021  11:28    <DIR>          .jupyter
# 28-07-2020  20:31    <DIR>          .m2
# 14-12-2019  15:17    <DIR>          .nbi
# 29-06-2021  14:50    <DIR>          .p2
# 02-12-2021  09:25    <DIR>          .spyder-py3
# 11-03-2020  18:33    <DIR>          .tooling
# 25-03-2022  09:05               762 .viminfo
# 25-12-2021  16:01    <DIR>          .VirtualBox
# 14-12-2019  18:39    <DIR>          .vscode
# 13-03-2022  15:36    <DIR>          __pycache__
# 26-12-2021  09:38             3,504 21st dec(for,while).ipynb
# 24-08-2021  15:06    <DIR>          3D Objects
# 23-03-2022  17:10             7,566 Abstraction.ipynb
# 14-02-2020  12:38    <DIR>          AndroidStudioProjects
# 28-01-2022  11:39               149 arithmatic.py
# 04-04-2022  09:01            51,867 car.data
# 07-04-2022  16:34           628,633 carbon_nanotubes.csv
# 15-04-2022  16:33             1,631 Casandra.ipynb
# 21-12-2021  12:45             7,578 conditional statement.ipynb
# 16-01-2022  15:37    <DIR>          Contacts
# 17-04-2022  13:02    <DIR>          Desktop
# 07-03-2022  18:09    <DIR>          Documents
# 17-04-2022  12:37    <DIR>          Downloads
# 29-06-2021  14:05    <DIR>          eclipse
# 29-06-2021  12:21    <DIR>          eclipse-workspace
# 02-02-2022  20:52            33,366 Exception Handling.ipynb
# 16-01-2022  15:37    <DIR>          Favorites
# 24-12-2021  14:54            13,457 for, while,lambda.ipynb
# 11-01-2022  16:25            34,720 function with argument,iterable,iterator.ipynb
# 29-12-2021  12:40            14,911 Function(23th Dec).ipynb
# 18-01-2022  16:02            67,764 generator,file operation.ipynb
# 01-04-2022  11:24            11,903 glass.data
# 16-10-2021  14:43    <DIR>          IBA_IOAPDATA
# 14-04-2022  08:13             8,192 ineuron.db
# 21-03-2022  15:51            51,131 Inheritance.ipynb
# 14-04-2022  13:35            12,288 joindb.db
# 16-01-2022  15:37    <DIR>          Links
# 16-04-2022  14:30           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 16-04-2022  14:30           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 16-04-2022  14:30            95,503 LUSID Excel - Manage instruments with economic definitions.xlsx
# 16-04-2022  14:30            84,319 LUSID Excel - Manage Orders.xlsx
# 16-04-2022  14:30           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 16-04-2022  14:30           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 16-04-2022  14:30           136,632 LUSID Excel - Setting up your market data.xlsx
# 28-01-2022  12:37             8,176 modules and package.ipynb
# 07-04-2022  16:41            37,174 Mongodb.ipynb
# 16-01-2022  15:37    <DIR>          Music
# 13-03-2022  15:35               635 mydict.py
# 18-04-2022  13:38            78,961 NBA.csv
# 27-01-2022  11:26    <DIR>          OneDrive
# 13-03-2022  16:07             1,641 Oops(Part1).ipynb
# 13-03-2022  20:42            17,056 oops.ipynb
# 14-12-2019  15:55    <DIR>          Oracle
# 18-04-2022  13:49            50,917 Pandas(2).ipynb
# 18-04-2022  12:32           206,347 Pandas.ipynb
# 14-04-2022  08:11             8,192 person.db
# 16-01-2022  15:37    <DIR>          Pictures
# 23-03-2022  17:10             9,704 polymorphism.ipynb
# 09-03-2022  09:11    <DIR>          PycharmProjects
# 25-03-2022  09:14    <DIR>          Python
# 19-01-2022  16:27            37,898 Questions.ipynb
# 16-04-2022  13:53               244 sample_test.csv
# 16-01-2022  15:37    <DIR>          Saved Games
# 16-01-2022  15:37    <DIR>          Searches
# 14-12-2019  18:13    <DIR>          source
# 01-04-2022  13:05           124,230 sql connection(part-1).ipynb
# 04-04-2022  13:47           492,986 sql(part-2).ipynb
# 14-04-2022  16:22            64,198 SqlLite,map,reduce,filter,zip.ipynb
# 16-11-2020  19:41       114,273,560 Teams_windows_x64.exe
# 25-01-2022  21:15               179 test.log
# 18-01-2022  14:34                 0 test.txt
# 16-03-2022  21:25                22 test1.txt
# 25-01-2022  21:34               719 test2.log
# 18-01-2022  14:40                21 test2.txt
# 28-01-2022  11:31               154 test22.py
# 25-01-2022  21:38                 0 test3.log
# 18-01-2022  14:30                 0 text.txt
# 28-11-2021  09:11    <DIR>          Tracing
# 30-03-2022  15:47             1,858 Untitled.ipynb
# 04-12-2021  14:23            14,021 Untitled1.ipynb
# 11-01-2022  16:09            34,720 Untitled15.ipynb
# 12-01-2022  14:08             4,789 Untitled16.ipynb
# 05-12-2021  13:48            15,628 Untitled2.ipynb
# 18-12-2021  15:27            17,346 Untitled3.ipynb
# 22-01-2022  13:11            12,826 Untitled4.ipynb
# 19-12-2021  12:54             7,580 Untitled5.ipynb
# 21-12-2021  12:33             3,794 Untitled6.ipynb
# 23-03-2022  10:42                72 Untitled7.ipynb
# 23-03-2022  14:29                72 Untitled8.ipynb
# 16-01-2022  15:37    <DIR>          Videos
# 16-11-2020  19:16       102,233,600 webexapp.msi
# 27-12-2021  10:39            10,289 while.ipynb
#               67 File(s)    219,694,028 bytes
#               46 Dir(s)  118,763,601,920 bytes free

# %%
df=pd.read_html('https://stats.espncricinfo.com/ci/content/records/135790.html')

# %%
df[0]
# Out:
#             Team   Score    Overs    RR  Inns  Unnamed: 5      Opposition  \
# 0       Victoria    1107  190.7x8  4.34     2         NaN           v NSW
# 1       Victoria    1059  186.0x8  4.27     2         NaN      v Tasmania
# 2      Sri Lanka  952/6d    271.0  3.51     2         NaN         v India
# 3           Sind  951/7d  179.4x8  3.97     2         NaN   v Baluchistan
# 4      Hyderabad  944/6d    211.0  4.47     2         NaN        v Andhra
# 5            NSW     918    208.0  4.41     2         NaN    v South Aust
# 6     Tamil Nadu  912/6d    191.2  4.76     1         NaN           v Goa
# 7         Holkar  912/8d    214.5  4.24     1         NaN        v Mysore
# 8     P Railways  910/6d    172.0  5.29     1         NaN   v Dera Ismail
# 9        England  903/7d    335.2  2.69     1         NaN     v Australia
# 10    Queensland  900/6d    242.0  3.71     2         NaN      v Victoria
# 11     Yorkshire     887  274.3x5  3.87     1         NaN  v Warwickshire
# 12     Jharkhand     880    203.4  4.32     1         NaN      v Nagaland
# 13    North Zone     868    197.0  4.40     2         NaN     v West Zone
# 14  Boost Region  864/9d    212.0  4.07     1         NaN    v Speen-Ghar
# 15    Lancashire     863    224.5  3.83     2         NaN        v Surrey
# 16        Bombay  855/6d    176.0  4.85     1         NaN     v Hyderabad
# 17      Somerset  850/7d    178.3  4.76     2         NaN     v Middlesex
#
#            Ground   Match Date    Scorecard
# 0       Melbourne  24 Dec 1926           FC
# 1       Melbourne   2 Feb 1923           FC
# 2   Colombo (RPS)   2 Aug 1997  Test # 1374
# 3         Karachi  18 Feb 1974           FC
# 4    Secunderabad   8 Jan 1994           FC
# 5          Sydney   5 Jan 1901           FC
# 6          Panaji  20 Jan 1989           FC
# 7          Indore   2 Mar 1946           FC
# 8          Lahore   2 Dec 1964           FC
# 9        The Oval  20 Aug 1938   Test # 266
# 10       Brisbane  24 Mar 2006           FC
# 11     Birmingham   7 May 1896           FC
# 12        Kolkata  12 Mar 2022           FC
# 13         Bhilai  21 Oct 1987           FC
# 14       Kandahar   2 Dec 2021           FC
# 15       The Oval   3 May 1990           FC
# 16       Wankhede  24 Apr 1991           FC
# 17        Taunton  18 Apr 2007           FC

# %%
df1=df[0]

# %%
df1.to_csv('cricket.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\Users\PRASHA~1\AppData\Local\Temp/ipykernel_328/3819161715.py in <module>
# ----> 1 df1.to_csv('cricket.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: 'cricket.csv'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1E4D-DCE3
#
#  Directory of C:\Users\PRASHANT KUMAR
#
# 18-04-2022  14:31    <DIR>          .
# 16-01-2022  13:18    <DIR>          ..
# 15-12-2019  12:13    <DIR>          .anaconda
# 14-02-2020  11:35    <DIR>          .android
# 17-01-2020  11:04    <DIR>          .AndroidStudio3.5
# 21-07-2020  17:20               145 .appletviewer
# 25-03-2022  10:52             1,010 .bash_history
# 29-06-2021  14:36    <DIR>          .cache
# 25-02-2022  09:33    <DIR>          .conda
# 15-10-2020  13:05                43 .condarc
# 08-02-2020  15:55    <DIR>          .config
# 28-11-2021  13:34    <DIR>          .continuum
# 14-06-2020  13:49    <DIR>          .dotnet
# 11-03-2020  18:33    <DIR>          .eclipse
# 17-01-2020  11:55                16 .emulator_console_auth_token
# 25-03-2022  09:44               214 .gitconfig
# 25-03-2022  09:04            12,288 .gitconfig.swp
# 17-01-2020  11:55    <DIR>          .gradle
# 07-02-2020  16:05    <DIR>          .idlerc
# 18-04-2022  12:33    <DIR>          .ipynb_checkpoints
# 15-12-2019  01:37    <DIR>          .ipython
# 19-12-2021  11:28    <DIR>          .jupyter
# 28-07-2020  20:31    <DIR>          .m2
# 14-12-2019  15:17    <DIR>          .nbi
# 29-06-2021  14:50    <DIR>          .p2
# 02-12-2021  09:25    <DIR>          .spyder-py3
# 11-03-2020  18:33    <DIR>          .tooling
# 25-03-2022  09:05               762 .viminfo
# 25-12-2021  16:01    <DIR>          .VirtualBox
# 14-12-2019  18:39    <DIR>          .vscode
# 13-03-2022  15:36    <DIR>          __pycache__
# 26-12-2021  09:38             3,504 21st dec(for,while).ipynb
# 24-08-2021  15:06    <DIR>          3D Objects
# 23-03-2022  17:10             7,566 Abstraction.ipynb
# 14-02-2020  12:38    <DIR>          AndroidStudioProjects
# 28-01-2022  11:39               149 arithmatic.py
# 04-04-2022  09:01            51,867 car.data
# 07-04-2022  16:34           628,633 carbon_nanotubes.csv
# 15-04-2022  16:33             1,631 Casandra.ipynb
# 21-12-2021  12:45             7,578 conditional statement.ipynb
# 16-01-2022  15:37    <DIR>          Contacts
# 18-04-2022  14:16             1,308 cricket.csv
# 17-04-2022  13:02    <DIR>          Desktop
# 07-03-2022  18:09    <DIR>          Documents
# 17-04-2022  12:37    <DIR>          Downloads
# 29-06-2021  14:05    <DIR>          eclipse
# 29-06-2021  12:21    <DIR>          eclipse-workspace
# 02-02-2022  20:52            33,366 Exception Handling.ipynb
# 16-01-2022  15:37    <DIR>          Favorites
# 24-12-2021  14:54            13,457 for, while,lambda.ipynb
# 11-01-2022  16:25            34,720 function with argument,iterable,iterator.ipynb
# 29-12-2021  12:40            14,911 Function(23th Dec).ipynb
# 18-01-2022  16:02            67,764 generator,file operation.ipynb
# 01-04-2022  11:24            11,903 glass.data
# 16-10-2021  14:43    <DIR>          IBA_IOAPDATA
# 14-04-2022  08:13             8,192 ineuron.db
# 21-03-2022  15:51            51,131 Inheritance.ipynb
# 14-04-2022  13:35            12,288 joindb.db
# 16-01-2022  15:37    <DIR>          Links
# 16-04-2022  14:30           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 16-04-2022  14:30           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 16-04-2022  14:30            95,503 LUSID Excel - Manage instruments with economic definitions.xlsx
# 16-04-2022  14:30            84,319 LUSID Excel - Manage Orders.xlsx
# 16-04-2022  14:30           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 16-04-2022  14:30           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 16-04-2022  14:30           136,632 LUSID Excel - Setting up your market data.xlsx
# 28-01-2022  12:37             8,176 modules and package.ipynb
# 07-04-2022  16:41            37,174 Mongodb.ipynb
# 16-01-2022  15:37    <DIR>          Music
# 13-03-2022  15:35               635 mydict.py
# 18-04-2022  13:38            78,961 NBA.csv
# 27-01-2022  11:26    <DIR>          OneDrive
# 13-03-2022  16:07             1,641 Oops(Part1).ipynb
# 13-03-2022  20:42            17,056 oops.ipynb
# 14-12-2019  15:55    <DIR>          Oracle
# 18-04-2022  14:31           103,370 Pandas(2).ipynb
# 18-04-2022  12:32           206,347 Pandas.ipynb
# 14-04-2022  08:11             8,192 person.db
# 16-01-2022  15:37    <DIR>          Pictures
# 23-03-2022  17:10             9,704 polymorphism.ipynb
# 09-03-2022  09:11    <DIR>          PycharmProjects
# 25-03-2022  09:14    <DIR>          Python
# 19-01-2022  16:27            37,898 Questions.ipynb
# 16-04-2022  13:53               244 sample_test.csv
# 16-01-2022  15:37    <DIR>          Saved Games
# 16-01-2022  15:37    <DIR>          Searches
# 14-12-2019  18:13    <DIR>          source
# 01-04-2022  13:05           124,230 sql connection(part-1).ipynb
# 04-04-2022  13:47           492,986 sql(part-2).ipynb
# 14-04-2022  16:22            64,198 SqlLite,map,reduce,filter,zip.ipynb
# 16-11-2020  19:41       114,273,560 Teams_windows_x64.exe
# 25-01-2022  21:15               179 test.log
# 18-01-2022  14:34                 0 test.txt
# 16-03-2022  21:25                22 test1.txt
# 25-01-2022  21:34               719 test2.log
# 18-01-2022  14:40                21 test2.txt
# 28-01-2022  11:31               154 test22.py
# 25-01-2022  21:38                 0 test3.log
# 18-01-2022  14:30                 0 text.txt
# 28-11-2021  09:11    <DIR>          Tracing
# 30-03-2022  15:47             1,858 Untitled.ipynb
# 04-12-2021  14:23            14,021 Untitled1.ipynb
# 11-01-2022  16:09            34,720 Untitled15.ipynb
# 12-01-2022  14:08             4,789 Untitled16.ipynb
# 05-12-2021  13:48            15,628 Untitled2.ipynb
# 18-12-2021  15:27            17,346 Untitled3.ipynb
# 22-01-2022  13:11            12,826 Untitled4.ipynb
# 19-12-2021  12:54             7,580 Untitled5.ipynb
# 21-12-2021  12:33             3,794 Untitled6.ipynb
# 23-03-2022  10:42                72 Untitled7.ipynb
# 23-03-2022  14:29                72 Untitled8.ipynb
# 16-01-2022  15:37    <DIR>          Videos
# 16-11-2020  19:16       102,233,600 webexapp.msi
# 27-12-2021  10:39            10,289 while.ipynb
#               68 File(s)    219,747,789 bytes
#               46 Dir(s)  118,733,934,592 bytes free

# %%
len(df)
# Out:
# 2

# %%
df[0]
# Out:
#             Team   Score    Overs    RR  Inns  Unnamed: 5      Opposition  \
# 0       Victoria    1107  190.7x8  4.34     2         NaN           v NSW
# 1       Victoria    1059  186.0x8  4.27     2         NaN      v Tasmania
# 2      Sri Lanka  952/6d    271.0  3.51     2         NaN         v India
# 3           Sind  951/7d  179.4x8  3.97     2         NaN   v Baluchistan
# 4      Hyderabad  944/6d    211.0  4.47     2         NaN        v Andhra
# 5            NSW     918    208.0  4.41     2         NaN    v South Aust
# 6     Tamil Nadu  912/6d    191.2  4.76     1         NaN           v Goa
# 7         Holkar  912/8d    214.5  4.24     1         NaN        v Mysore
# 8     P Railways  910/6d    172.0  5.29     1         NaN   v Dera Ismail
# 9        England  903/7d    335.2  2.69     1         NaN     v Australia
# 10    Queensland  900/6d    242.0  3.71     2         NaN      v Victoria
# 11     Yorkshire     887  274.3x5  3.87     1         NaN  v Warwickshire
# 12     Jharkhand     880    203.4  4.32     1         NaN      v Nagaland
# 13    North Zone     868    197.0  4.40     2         NaN     v West Zone
# 14  Boost Region  864/9d    212.0  4.07     1         NaN    v Speen-Ghar
# 15    Lancashire     863    224.5  3.83     2         NaN        v Surrey
# 16        Bombay  855/6d    176.0  4.85     1         NaN     v Hyderabad
# 17      Somerset  850/7d    178.3  4.76     2         NaN     v Middlesex
#
#            Ground   Match Date    Scorecard
# 0       Melbourne  24 Dec 1926           FC
# 1       Melbourne   2 Feb 1923           FC
# 2   Colombo (RPS)   2 Aug 1997  Test # 1374
# 3         Karachi  18 Feb 1974           FC
# 4    Secunderabad   8 Jan 1994           FC
# 5          Sydney   5 Jan 1901           FC
# 6          Panaji  20 Jan 1989           FC
# 7          Indore   2 Mar 1946           FC
# 8          Lahore   2 Dec 1964           FC
# 9        The Oval  20 Aug 1938   Test # 266
# 10       Brisbane  24 Mar 2006           FC
# 11     Birmingham   7 May 1896           FC
# 12        Kolkata  12 Mar 2022           FC
# 13         Bhilai  21 Oct 1987           FC
# 14       Kandahar   2 Dec 2021           FC
# 15       The Oval   3 May 1990           FC
# 16       Wankhede  24 Apr 1991           FC
# 17        Taunton  18 Apr 2007           FC

# %%
df[1]
# Out:
#                                                    0
# 0     Records includes the following recent matches:
# 1  Derbyshire v Sussex at Derby, County Champions...
# 2  Durham v Leicestershire at Chester-le-Street, ...
# 3  Gloucestershire v Yorkshire at Bristol, County...
# 4  Kent v Lancashire at Canterbury, County Champi...
# 5  Nottinghamshire v Glamorgan at Nottingham, Cou...

# %%
df[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\PRASHA~1\AppData\Local\Temp/ipykernel_328/846428512.py in <module>
# ----> 1 df[3]
#
# IndexError: list index out of range

# %%
df1.to_csv('cricket.csv',index=False)

# %%
import pandas as pd

# %%
df=pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
df
# Out:
# [               Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
#  0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
#  1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
#  2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
#  3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
#  4          Avesh Khan  2022-2022    2    -  -     -    -      -    -       -
#  ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
#  92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
#  93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
#  94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
#  95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
#  96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#     100 50  0  4s  6s
#  0    0  0  0   2   0
#  1    0  0  0   0   0
#  2    -  -  -   -   -
#  3    0  0  0  14   1
#  4    -  -  -   -   -
#  ..  .. .. ..  ..  ..
#  92   0  0  0   0   0
#  93   0  0  3   4   3
#  94   0  4  1  32  20
#  95   0  0  0   0   0
#  96   0  8  1  77  74
#
#  [97 rows x 15 columns],
#                                                     0
#  0  By default, the shading indicates records from...
#  1  Adjust:  most recent  | past week  | past mont...,
#                                                     0
#  0  Records includes the following current or rece...
#  1  India v Sri Lanka at Dharamsala, 3rd T20I, Feb...
#  2  India v Sri Lanka at Dharamsala, 2nd T20I, Feb...
#  3  India v Sri Lanka at Lucknow, 1st T20I, Feb 24...]

# %%
len(df)
# Out:
# 3

# %%
df[0].to_csv('icc.csv',index=False)

# %%
df[0]
# Out:
#                Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
# 0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
# 1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
# 2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
# 3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
# 4          Avesh Khan  2022-2022    2    -  -     -    -      -    -       -
# ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
# 92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
# 93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
# 94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
# 95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
# 96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#    100 50  0  4s  6s
# 0    0  0  0   2   0
# 1    0  0  0   0   0
# 2    -  -  -   -   -
# 3    0  0  0  14   1
# 4    -  -  -   -   -
# ..  .. .. ..  ..  ..
# 92   0  0  0   0   0
# 93   0  0  3   4   3
# 94   0  4  1  32  20
# 95   0  0  0   0   0
# 96   0  8  1  77  74
#
# [97 rows x 15 columns]

# %%
df[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
df[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  India v Sri Lanka at Dharamsala, 3rd T20I, Feb...
# 2  India v Sri Lanka at Dharamsala, 2nd T20I, Feb...
# 3  India v Sri Lanka at Lucknow, 1st T20I, Feb 24...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1E4D-DCE3
#
#  Directory of C:\Users\PRASHANT KUMAR
#
# 19-04-2022  13:15    <DIR>          .
# 16-01-2022  13:18    <DIR>          ..
# 15-12-2019  12:13    <DIR>          .anaconda
# 14-02-2020  11:35    <DIR>          .android
# 17-01-2020  11:04    <DIR>          .AndroidStudio3.5
# 21-07-2020  17:20               145 .appletviewer
# 25-03-2022  10:52             1,010 .bash_history
# 29-06-2021  14:36    <DIR>          .cache
# 25-02-2022  09:33    <DIR>          .conda
# 15-10-2020  13:05                43 .condarc
# 08-02-2020  15:55    <DIR>          .config
# 28-11-2021  13:34    <DIR>          .continuum
# 14-06-2020  13:49    <DIR>          .dotnet
# 11-03-2020  18:33    <DIR>          .eclipse
# 17-01-2020  11:55                16 .emulator_console_auth_token
# 25-03-2022  09:44               214 .gitconfig
# 25-03-2022  09:04            12,288 .gitconfig.swp
# 17-01-2020  11:55    <DIR>          .gradle
# 07-02-2020  16:05    <DIR>          .idlerc
# 19-04-2022  13:12    <DIR>          .ipynb_checkpoints
# 15-12-2019  01:37    <DIR>          .ipython
# 19-12-2021  11:28    <DIR>          .jupyter
# 28-07-2020  20:31    <DIR>          .m2
# 14-12-2019  15:17    <DIR>          .nbi
# 29-06-2021  14:50    <DIR>          .p2
# 02-12-2021  09:25    <DIR>          .spyder-py3
# 11-03-2020  18:33    <DIR>          .tooling
# 25-03-2022  09:05               762 .viminfo
# 25-12-2021  16:01    <DIR>          .VirtualBox
# 14-12-2019  18:39    <DIR>          .vscode
# 13-03-2022  15:36    <DIR>          __pycache__
# 26-12-2021  09:38             3,504 21st dec(for,while).ipynb
# 24-08-2021  15:06    <DIR>          3D Objects
# 23-03-2022  17:10             7,566 Abstraction.ipynb
# 14-02-2020  12:38    <DIR>          AndroidStudioProjects
# 28-01-2022  11:39               149 arithmatic.py
# 04-04-2022  09:01            51,867 car.data
# 07-04-2022  16:34           628,633 carbon_nanotubes.csv
# 15-04-2022  16:33             1,631 Casandra.ipynb
# 21-12-2021  12:45             7,578 conditional statement.ipynb
# 16-01-2022  15:37    <DIR>          Contacts
# 18-04-2022  14:16             1,308 cricket.csv
# 18-04-2022  14:45    <DIR>          Desktop
# 07-03-2022  18:09    <DIR>          Documents
# 19-04-2022  13:10    <DIR>          Downloads
# 29-06-2021  14:05    <DIR>          eclipse
# 29-06-2021  12:21    <DIR>          eclipse-workspace
# 02-02-2022  20:52            33,366 Exception Handling.ipynb
# 16-01-2022  15:37    <DIR>          Favorites
# 24-12-2021  14:54            13,457 for, while,lambda.ipynb
# 11-01-2022  16:25            34,720 function with argument,iterable,iterator.ipynb
# 29-12-2021  12:40            14,911 Function(23th Dec).ipynb
# 18-01-2022  16:02            67,764 generator,file operation.ipynb
# 01-04-2022  11:24            11,903 glass.data
# 16-10-2021  14:43    <DIR>          IBA_IOAPDATA
# 19-04-2022  13:15             5,658 icc.csv
# 14-04-2022  08:13             8,192 ineuron.db
# 21-03-2022  15:51            51,131 Inheritance.ipynb
# 14-04-2022  13:35            12,288 joindb.db
# 16-01-2022  15:37    <DIR>          Links
# 16-04-2022  14:30           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 16-04-2022  14:30           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 16-04-2022  14:30            95,503 LUSID Excel - Manage instruments with economic definitions.xlsx
# 16-04-2022  14:30            84,319 LUSID Excel - Manage Orders.xlsx
# 16-04-2022  14:30           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 16-04-2022  14:30           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 16-04-2022  14:30           136,632 LUSID Excel - Setting up your market data.xlsx
# 28-01-2022  12:37             8,176 modules and package.ipynb
# 07-04-2022  16:41            37,174 Mongodb.ipynb
# 16-01-2022  15:37    <DIR>          Music
# 13-03-2022  15:35               635 mydict.py
# 18-04-2022  13:38            78,961 NBA.csv
# 27-01-2022  11:26    <DIR>          OneDrive
# 13-03-2022  16:07             1,641 Oops(Part1).ipynb
# 13-03-2022  20:42            17,056 oops.ipynb
# 14-12-2019  15:55    <DIR>          Oracle
# 19-04-2022  13:12           576,990 pandas day 2.ipynb
# 19-04-2022  13:15           102,896 Pandas(2).ipynb
# 18-04-2022  12:32           206,347 Pandas.ipynb
# 14-04-2022  08:11             8,192 person.db
# 16-01-2022  15:37    <DIR>          Pictures
# 23-03-2022  17:10             9,704 polymorphism.ipynb
# 09-03-2022  09:11    <DIR>          PycharmProjects
# 25-03-2022  09:14    <DIR>          Python
# 19-01-2022  16:27            37,898 Questions.ipynb
# 16-04-2022  13:53               244 sample_test.csv
# 16-01-2022  15:37    <DIR>          Saved Games
# 16-01-2022  15:37    <DIR>          Searches
# 14-12-2019  18:13    <DIR>          source
# 01-04-2022  13:05           124,230 sql connection(part-1).ipynb
# 04-04-2022  13:47           492,986 sql(part-2).ipynb
# 14-04-2022  16:22            64,198 SqlLite,map,reduce,filter,zip.ipynb
# 16-11-2020  19:41       114,273,560 Teams_windows_x64.exe
# 25-01-2022  21:15               179 test.log
# 18-01-2022  14:34                 0 test.txt
# 16-03-2022  21:25                22 test1.txt
# 25-01-2022  21:34               719 test2.log
# 18-01-2022  14:40                21 test2.txt
# 28-01-2022  11:31               154 test22.py
# 25-01-2022  21:38                 0 test3.log
# 18-01-2022  14:30                 0 text.txt
# 28-11-2021  09:11    <DIR>          Tracing
# 30-03-2022  15:47             1,858 Untitled.ipynb
# 04-12-2021  14:23            14,021 Untitled1.ipynb
# 11-01-2022  16:09            34,720 Untitled15.ipynb
# 12-01-2022  14:08             4,789 Untitled16.ipynb
# 05-12-2021  13:48            15,628 Untitled2.ipynb
# 18-12-2021  15:27            17,346 Untitled3.ipynb
# 22-01-2022  13:11            12,826 Untitled4.ipynb
# 19-12-2021  12:54             7,580 Untitled5.ipynb
# 21-12-2021  12:33             3,794 Untitled6.ipynb
# 23-03-2022  10:42                72 Untitled7.ipynb
# 23-03-2022  14:29                72 Untitled8.ipynb
# 16-01-2022  15:37    <DIR>          Videos
# 16-11-2020  19:16       102,233,600 webexapp.msi
# 27-12-2021  10:39            10,289 while.ipynb
#               70 File(s)    220,329,963 bytes
#               46 Dir(s)  119,114,342,400 bytes free

# %%
d="""
{
"name":"prashant Kumar",
"email":"prasantk065@gmail.com",
"tech":["ML","DL","CV","NLP","RL","BD","DA"],
"plateform":["techneuron","kidsneuron","ineuron"]
}
"""

# %%
type(d)
# Out:
# str

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\PRASHA~1\AppData\Local\Temp/ipykernel_4872/2567112034.py in <module>
# ----> 1 pd.DataFrame(d)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
import json

# %%
result=json.loads(d)

# %%
result
# Out:
# {'name': 'prashant Kumar',
#  'email': 'prasantk065@gmail.com',
#  'tech': ['ML', 'DL', 'CV', 'NLP', 'RL', 'BD', 'DA'],
#  'plateform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\PRASHA~1\AppData\Local\Temp/ipykernel_4872/3023930414.py in <module>
# ----> 1 pd.DataFrame(result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
pd.read_json(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\PRASHA~1\AppData\Local\Temp/ipykernel_4872/3565998326.py in <module>
# ----> 1 pd.read_json(result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     588         convert_axes = True
#     589
# --> 590     json_reader = JsonReader(
#     591         path_or_buf,
#     592         orient=orient,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in __init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors)
#     673                 raise ValueError("nrows can only be passed if lines=True")
#     674
# --> 675         data = self._get_data_from_filepath(filepath_or_buffer)
#     676         self.data = self._preprocess_data(data)
#     677
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in _get_data_from_filepath(self, filepath_or_buffer)
#     710             or file_exists(filepath_or_buffer)
#     711         ):
# --> 712             self.handles = get_handle(
#     713                 filepath_or_buffer,
#     714                 "r",
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     607
#     608     # open URLs
# --> 609     ioargs = _get_filepath_or_buffer(
#     610         path_or_buf,
#     611         encoding=encoding,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     394     if not is_file_like(filepath_or_buffer):
#     395         msg = f"Invalid file path or buffer object type: {type(filepath_or_buffer)}"
# --> 396         raise ValueError(msg)
#     397
#     398     return IOArgs(
#
# ValueError: Invalid file path or buffer object type: <class 'dict'>

# %%
d1="""
{
"name":"prashant Kumar",
"email":"prasantk065@gmail.com",
"tech":["ML","DL","CV"],
"plateform":["techneuron","kidsneuron","ineuron"]
}
"""

# %%
r1=json.loads(d1)

# %%
r1
# Out:
# {'name': 'prashant Kumar',
#  'email': 'prasantk065@gmail.com',
#  'tech': ['ML', 'DL', 'CV'],
#  'plateform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
pd.DataFrame(r1)
# Out:
#              name                  email tech   plateform
# 0  prashant Kumar  prasantk065@gmail.com   ML  techneuron
# 1  prashant Kumar  prasantk065@gmail.com   DL  kidsneuron
# 2  prashant Kumar  prasantk065@gmail.com   CV     ineuron

# %%
result['name']
# Out:
# 'prashant Kumar'

# %%
pd.DataFrame(result['name'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\PRASHA~1\AppData\Local\Temp/ipykernel_4872/268115432.py in <module>
# ----> 1 pd.DataFrame(result['name'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
pd.DataFrame(result['tech'])
# Out:
#      0
# 0   ML
# 1   DL
# 2   CV
# 3  NLP
# 4   RL
# 5   BD
# 6   DA

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
pd.DataFrame(d)
# Out:
#                          packetType  \
# checkEngineLightFlag              D
# batteryVoltageStableTime          D
# batteryVoltageStable              D
# batteryVoltageOff                 D
# batteryCrankParamTN               D
# batteryCrankParamVN               D
# batteryCrankParamTP               D
# batteryCrankParamVP               D
# batteryCrankParamTT               D
# batteryCrankParamV0               D
# batteryVoltageMaxOn               D
# batteryVoltageMinOn               D
# batteryVoltageMaxOff              D
# batteryVoltageMinOff              D
# batteryVoltageOnAverage           D
# engineLoadMax                     D
# engineLoadAverage                 D
# rpmMax                            D
# rpmAverage                        D
# gpsSpeedAverage                   D
# vssMax                            D
# vssAverage                        D
# tcuTemperatureMin                 D
# tcuTemperatureMax                 D
# tcuTemperatureAverage             D
# coolantMin                        D
# coolantMax                        D
# coolantAverage                    D
# packetStartLocal                  D
# tripStartLocal                    D
# milIndicator                      D
# monitorsNotReady                  D
# imei                              D
# gatewayTs                         D
# diagnosticPidData                 D
# iwrapVer                          D
# sourceSystem                      D
# configVer                         D
# oemName                           D
# unitType                          D
# cpVer                             D
# igpsVer                           D
# messageType                       D
# pomVer                            D
# headerVer                         D
# timestamp                         D
# deviceType                        D
# visorVer                          D
# transactionId                     D
# deviceSerialNo                    D
# subOrganization                   D
# organization                      D
# operation                         D
#
#                                                                        data  \
# checkEngineLightFlag                                                      F
# batteryVoltageStableTime                                                  0
# batteryVoltageStable                                                      0
# batteryVoltageOff                                                     12.42
# batteryCrankParamTN                                                   -0.08
# batteryCrankParamVN                                                    0.00
# batteryCrankParamTP                                                   -0.08
# batteryCrankParamVP                                                    0.00
# batteryCrankParamTT                                                -0.00008
# batteryCrankParamV0                                                    0.00
# batteryVoltageMaxOn                                                   13.05
# batteryVoltageMinOn                                                   12.97
# batteryVoltageMaxOff                                                  12.46
# batteryVoltageMinOff                                                  12.36
# batteryVoltageOnAverage                                               13.02
# engineLoadMax                                                            84
# engineLoadAverage                                                     39.98
# rpmMax                                                                 3487
# rpmAverage                                                          1431.29
# gpsSpeedAverage                                                       21.99
# vssMax                                                                53.44
# vssAverage                                                            23.06
# tcuTemperatureMin                                                     82.40
# tcuTemperatureMax                                                    109.40
# tcuTemperatureAverage                                                104.87
# coolantMin                                                           158.00
# coolantMax                                                           188.60
# coolantAverage                                                       180.20
# packetStartLocal                                              1508143346000
# tripStartLocal                                                1508143346000
# milIndicator                                                              F
# monitorsNotReady                                                          0
# imei                                                               60DF5417
# gatewayTs                                                     1515613306592
# diagnosticPidData         [[64768, 47, 100], [64768, 1, 517376], [64800,...
# iwrapVer                                                                NaN
# sourceSystem                                                            NaN
# configVer                                                               NaN
# oemName                                                                 NaN
# unitType                                                                NaN
# cpVer                                                                   NaN
# igpsVer                                                                 NaN
# messageType                                                             NaN
# pomVer                                                                  NaN
# headerVer                                                               NaN
# timestamp                                                               NaN
# deviceType                                                              NaN
# visorVer                                                                NaN
# transactionId                                                           NaN
# deviceSerialNo                                                          NaN
# subOrganization                                                         NaN
# organization                                                            NaN
# operation                                                               NaN
#
#                                                         header
# checkEngineLightFlag                                       NaN
# batteryVoltageStableTime                                   NaN
# batteryVoltageStable                                       NaN
# batteryVoltageOff                                          NaN
# batteryCrankParamTN                                        NaN
# batteryCrankParamVN                                        NaN
# batteryCrankParamTP                                        NaN
# batteryCrankParamVP                                        NaN
# batteryCrankParamTT                                        NaN
# batteryCrankParamV0                                        NaN
# batteryVoltageMaxOn                                        NaN
# batteryVoltageMinOn                                        NaN
# batteryVoltageMaxOff                                       NaN
# batteryVoltageMinOff                                       NaN
# batteryVoltageOnAverage                                    NaN
# engineLoadMax                                              NaN
# engineLoadAverage                                          NaN
# rpmMax                                                     NaN
# rpmAverage                                                 NaN
# gpsSpeedAverage                                            NaN
# vssMax                                                     NaN
# vssAverage                                                 NaN
# tcuTemperatureMin                                          NaN
# tcuTemperatureMax                                          NaN
# tcuTemperatureAverage                                      NaN
# coolantMin                                                 NaN
# coolantMax                                                 NaN
# coolantAverage                                             NaN
# packetStartLocal                                           NaN
# tripStartLocal                                             NaN
# milIndicator                                               NaN
# monitorsNotReady                                           NaN
# imei                                                  60DF5417
# gatewayTs                                                  NaN
# diagnosticPidData                                          NaN
# iwrapVer                                                1.9.20
# sourceSystem                                               CDP
# configVer                                                  1.1
# oemName                                                    HUM
# unitType                                                     0
# cpVer                                                 7.50.1.9
# igpsVer                                                  1.3.7
# messageType                                       Notification
# pomVer                                                     1.0
# headerVer                                                   V6
# timestamp                                                    0
# deviceType                                             InDrive
# visorVer                                                1.4.35
# transactionId             53098471-7787-4160-94b3-cd69dcc70416
# deviceSerialNo                                        60DF5417
# subOrganization                                            HUM
# organization                                               HUM
# operation                                         Notification

# %%
d1=d["data"]

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticTroubleCodeData': [],
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
del d1['diagnosticTroubleCodeData']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
pd.DataFrame(d['data'])
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# 3               -0.08                0.00            -0.00008
#
#   batteryCrankParamV0  ... coolantMin coolantMax coolantAverage  \
# 0                0.00  ...     158.00     188.60         180.20
# 1                0.00  ...     158.00     188.60         180.20
# 2                0.00  ...     158.00     188.60         180.20
# 3                0.00  ...     158.00     188.60         180.20
#
#   packetStartLocal tripStartLocal milIndicator monitorsNotReady      imei  \
# 0    1508143346000  1508143346000            F                0  60DF5417
# 1    1508143346000  1508143346000            F                0  60DF5417
# 2    1508143346000  1508143346000            F                0  60DF5417
# 3    1508143346000  1508143346000            F                0  60DF5417
#
#        gatewayTs   diagnosticPidData
# 0  1515613306592    [64768, 47, 100]
# 1  1515613306592  [64768, 1, 517376]
# 2  1515613306592  [64800, 1, 262144]
# 3  1515613306592     [64768, 5, 125]
#
# [4 rows x 35 columns]

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/46799  1207499980
# 1     https://github.com/pandas-dev/pandas/pull/46798  1207172802
# 2   https://github.com/pandas-dev/pandas/issues/46797  1206612518
# 3   https://github.com/pandas-dev/pandas/issues/46793  1206370745
# 4     https://github.com/pandas-dev/pandas/pull/46792  1206301209
# 5     https://github.com/pandas-dev/pandas/pull/46791  1206170540
# 6   https://github.com/pandas-dev/pandas/issues/46790  1206164359
# 7     https://github.com/pandas-dev/pandas/pull/46789  1206141718
# 8     https://github.com/pandas-dev/pandas/pull/46786  1205872267
# 9     https://github.com/pandas-dev/pandas/pull/46784  1205765682
# 10  https://github.com/pandas-dev/pandas/issues/46783  1205740295
# 11    https://github.com/pandas-dev/pandas/pull/46778  1204912401
# 12  https://github.com/pandas-dev/pandas/issues/46776  1204378879
# 13    https://github.com/pandas-dev/pandas/pull/46774  1204039393
# 14    https://github.com/pandas-dev/pandas/pull/46771  1203768268
# 15  https://github.com/pandas-dev/pandas/issues/46770  1203632158
# 16  https://github.com/pandas-dev/pandas/issues/46769  1203606102
# 17  https://github.com/pandas-dev/pandas/issues/46768  1203529564
# 18    https://github.com/pandas-dev/pandas/pull/46766  1203443826
# 19  https://github.com/pandas-dev/pandas/issues/46765  1203409750
# 20  https://github.com/pandas-dev/pandas/issues/46764  1203095324
# 21  https://github.com/pandas-dev/pandas/issues/46763  1203080465
# 22    https://github.com/pandas-dev/pandas/pull/46761  1202686797
# 23    https://github.com/pandas-dev/pandas/pull/46759  1202397187
# 24  https://github.com/pandas-dev/pandas/issues/46755  1202186120
# 25    https://github.com/pandas-dev/pandas/pull/46752  1201795845
# 26  https://github.com/pandas-dev/pandas/issues/46751  1201790266
# 27  https://github.com/pandas-dev/pandas/issues/46750  1201718237
# 28  https://github.com/pandas-dev/pandas/issues/46747  1201449320
# 29  https://github.com/pandas-dev/pandas/issues/46744  1200431802
#
#                 node_id  number  \
# 0    I_kwDOAA0YD85H-PzM   46799
# 1   PR_kwDOAA0YD842Xj3P   46798
# 2    I_kwDOAA0YD85H63Im   46797
# 3    I_kwDOAA0YD85H58G5   46793
# 4   PR_kwDOAA0YD842Uu8E   46792
# 5   PR_kwDOAA0YD842UW62   46791
# 6    I_kwDOAA0YD85H5JuH   46790
# 7   PR_kwDOAA0YD842UTSU   46789
# 8   PR_kwDOAA0YD842TiuU   46786
# 9   PR_kwDOAA0YD842TO4h   46784
# 10   I_kwDOAA0YD85H3iMH   46783
# 11  PR_kwDOAA0YD842QdlT   46778
# 12   I_kwDOAA0YD85HyVz_   46776
# 13  PR_kwDOAA0YD842NvHH   46774
# 14  PR_kwDOAA0YD842M2rW   46771
# 15   I_kwDOAA0YD85Hvfge   46770
# 16   I_kwDOAA0YD85HvZJW   46769
# 17   I_kwDOAA0YD85HvGdc   46768
# 18  PR_kwDOAA0YD842LxwD   46766
# 19   I_kwDOAA0YD85HupNW   46765
# 20   I_kwDOAA0YD85Htccc   46764
# 21   I_kwDOAA0YD85HtY0R   46763
# 22  PR_kwDOAA0YD842JXZ5   46761
# 23  PR_kwDOAA0YD842IXwv   46759
# 24   I_kwDOAA0YD85Hp-eI   46755
# 25  PR_kwDOAA0YD842GXHp   46752
# 26   I_kwDOAA0YD85Hod06   46751
# 27   I_kwDOAA0YD85HoMPd   46750
# 28   I_kwDOAA0YD85HnKlo   46747
# 29   I_kwDOAA0YD85HjSK6   46744
#
#                                                 title  ...  \
# 0   BUG: Merge fails on nullable integer columns w...  ...
# 1   BUG: `DataFrameGroupBy.value_counts` includes ...  ...
# 2   BUG:  pandas.cut  doesnt respect to `precision...  ...
# 3   WEB: Use mambaforge for the getting started in...  ...
# 4   DOC: Remove unused argument from resampler doc...  ...
# 5   Change `mylen` function to account for NaN emp...  ...
# 6   ENH: Add option for `bold_column_headers` to `...  ...
# 7           BUG: .fillna(-1) does not work in pd.eval  ...
# 8                             TYP: CallableDynamicDoc  ...
# 9   ENH: Added Index param to to_dict like in to_j...  ...
# 10  BUG: `dropna=False` not respected for groupby ...  ...
# 11  BUG: fixed buggy behavior in pivot_table with ...  ...
# 12                                           RLS: 2.0  ...
# 13                             ENH: Create ArrowDtype  ...
# 14  BUG: date_range not excluding dates correctly ...  ...
# 15  BUG: `CategoricalDtype(None, False)` does not ...  ...
# 16      BUG: Pandas Index fails with `bitwise` ufuncs  ...
# 17  DEPR: Deprecate daysinmonth, dayofweek, dayofyear  ...
# 18                 DOC: add examples to groupby.first  ...
# 19  BUG: unable to read sftp urls despite fsspec s...  ...
# 20          BUG: MultiIndex converts `"\x00"` to `""`  ...
# 21  DOC: Float64Index.get_loc is deprecation warni...  ...
# 22              TYP: add some properties to Timestamp  ...
# 23    [READY] Some faster date/time string formatting  ...
# 24  ENH: Add a Pandas display option and/or DataFr...  ...
# 25  BUG: Coerce to native types to_dict list and i...  ...
# 26  BUG: to_dict("index") and to_dict("list") don'...  ...
# 27  BUG: to_stata() creates corrupt output file wh...  ...
# 28  ENH: Always write directly to output in `to_pi...  ...
# 29  ENH: Support using repr() instead of str() to ...  ...
#
#                   updated_at closed_at author_association  active_lock_reason  \
# 0  2022-04-18 22:21:14+00:00       NaT        CONTRIBUTOR                 NaN
# 1  2022-04-18 21:11:22+00:00       NaT               NONE                 NaN
# 2  2022-04-18 03:20:23+00:00       NaT               NONE                 NaN
# 3  2022-04-17 13:07:21+00:00       NaT             MEMBER                 NaN
# 4  2022-04-19 04:01:29+00:00       NaT               NONE                 NaN
# 5  2022-04-19 03:06:01+00:00       NaT               NONE                 NaN
# 6  2022-04-18 07:21:23+00:00       NaT        CONTRIBUTOR                 NaN
# 7  2022-04-17 17:16:14+00:00       NaT               NONE                 NaN
# 8  2022-04-15 20:35:48+00:00       NaT        CONTRIBUTOR                 NaN
# 9  2022-04-15 20:49:32+00:00       NaT               NONE                 NaN
# 10 2022-04-15 21:57:07+00:00       NaT               NONE                 NaN
# 11 2022-04-18 17:27:13+00:00       NaT        CONTRIBUTOR                 NaN
# 12 2022-04-15 17:13:17+00:00       NaT             MEMBER                 NaN
# 13 2022-04-18 22:27:49+00:00       NaT             MEMBER                 NaN
# 14 2022-04-18 11:55:04+00:00       NaT        CONTRIBUTOR                 NaN
# 15 2022-04-14 11:24:46+00:00       NaT        CONTRIBUTOR                 NaN
# 16 2022-04-14 10:31:20+00:00       NaT               NONE                 NaN
# 17 2022-04-14 11:16:55+00:00       NaT        CONTRIBUTOR                 NaN
# 18 2022-04-18 17:52:00+00:00       NaT        CONTRIBUTOR                 NaN
# 19 2022-04-13 20:04:59+00:00       NaT               NONE                 NaN
# 20 2022-04-15 00:49:34+00:00       NaT               NONE                 NaN
# 21 2022-04-13 13:39:54+00:00       NaT               NONE                 NaN
# 22 2022-04-13 16:29:40+00:00       NaT        CONTRIBUTOR                 NaN
# 23 2022-04-13 09:00:22+00:00       NaT        CONTRIBUTOR                 NaN
# 24 2022-04-13 13:52:49+00:00       NaT               NONE                 NaN
# 25 2022-04-19 03:18:51+00:00       NaT               NONE                 NaN
# 26 2022-04-12 15:17:27+00:00       NaT               NONE                 NaN
# 27 2022-04-12 12:21:04+00:00       NaT               NONE                 NaN
# 28 2022-04-15 22:25:11+00:00       NaT               NONE                 NaN
# 29 2022-04-12 17:36:57+00:00       NaT               NONE                 NaN
#
#                                                  body  \
# 0   ### Pandas version checks\r\n\r\n- [X] I have ...
# 1   - [X] closes #46357\r\n- [X] [Tests added and ...
# 2   ### Pandas version checks\n\n- [X] I have chec...
# 3   We've got [this page](https://pandas.pydata.or...
# 4   - [ ] closes #46442 (Replace xxxx with the Git...
# 5   - [x] closes #46084 \r\n- [ ] [Tests added and...
# 6   In the latest pandas version 1.4.2 there exist...
# 7   Adding ```self.value``` resolves the issue #46...
# 8   The more tricky parts of #46698.\r\n\r\nAdding...
# 9   - [X] closes #46398 \r\n- [X] [Tests added and...
# 10  ### Pandas version checks\n\n- [X] I have chec...
# 11  - [X] closes #26568(Replace xxxx with the Gith...
# 12  Tracking issue for the 2.0 release. (Note: pan...
# 13  - [x] All [code checks passed](https://pandas....
# 14  - [x] closes #46331 (Replace xxxx with the Git...
# 15  ### Pandas version checks\r\n\r\n- [X] I have ...
# 16  ### Pandas version checks\n\n- [X] I have chec...
# 17  Based on original issue #1723 and https://gith...
# 18  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 19  ### Pandas version checks\r\n\r\n- [X] I have ...
# 20  ### Pandas version checks\r\n\r\n- [X] I have ...
# 21  ### Pandas version checks\r\n\r\n- [X] I have ...
# 22  For typing, add for `Timestamp`:\r\n- `dayofwe...
# 23  "Easy" fixes related to #44764, taken from the...
# 24  #### Is your feature request related to a prob...
# 25  - [x] closes #46751 (Replace xxxx with the Git...
# 26  ### Pandas version checks\n\n- [X] I have chec...
# 27  ### Pandas version checks\n\n- [X] I have chec...
# 28  #### Is your feature request related to a prob...
# 29  #### Is your feature request related to a prob...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#     performed_via_github_app draft  \
# 0                        NaN   NaN
# 1                        NaN   0.0
# 2                        NaN   NaN
# 3                        NaN   NaN
# 4                        NaN   0.0
# 5                        NaN   0.0
# 6                        NaN   NaN
# 7                        NaN   0.0
# 8                        NaN   1.0
# 9                        NaN   0.0
# 10                       NaN   NaN
# 11                       NaN   0.0
# 12                       NaN   NaN
# 13                       NaN   0.0
# 14                       NaN   0.0
# 15                       NaN   NaN
# 16                       NaN   NaN
# 17                       NaN   NaN
# 18                       NaN   0.0
# 19                       NaN   NaN
# 20                       NaN   NaN
# 21                       NaN   NaN
# 22                       NaN   0.0
# 23                       NaN   0.0
# 24                       NaN   NaN
# 25                       NaN   0.0
# 26                       NaN   NaN
# 27                       NaN   NaN
# 28                       NaN   NaN
# 29                       NaN   NaN
#
#                                          pull_request
# 0                                                 NaN
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2                                                 NaN
# 3                                                 NaN
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6                                                 NaN
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10                                                NaN
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
# [30 rows x 29 columns]

# %%
import requests
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1=data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46799',
#   'id': 1207499980,
#   'node_id': 'I_kwDOAA0YD85H-PzM',
#   'number': 46799,
#   'title': 'BUG: Merge fails on nullable integer columns when dtypes are unequal',
#   'user': {'login': 'NickCrews',
#    'id': 10820686,
#    'node_id': 'MDQ6VXNlcjEwODIwNjg2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10820686?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NickCrews',
#    'html_url': 'https://github.com/NickCrews',
#    'followers_url': 'https://api.github.com/users/NickCrews/followers',
#    'following_url': 'https://api.github.com/users/NickCrews/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/NickCrews/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/NickCrews/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/NickCrews/subscriptions',
#    'organizations_url': 'https://api.github.com/users/NickCrews/orgs',
#    'repos_url': 'https://api.github.com/users/NickCrews/repos',
#    'events_url': 'https://api.github.com/users/NickCrews/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/NickCrews/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-18T22:09:52Z',
#   'updated_at': '2022-04-18T22:21:14Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport numpy as np\r\nimport pandas as pd\r\n\r\nnull_keys = pd.DataFrame(\r\n    {\r\n        "key": pd.Series([0, 1, pd.NA], dtype=pd.Int64Dtype()),\r\n        "val1": pd.Series(["a", "b", "c"]),\r\n    }\r\n)\r\nnon_null_keys = pd.DataFrame(\r\n    {\r\n        "key": pd.Series([0, 1, 2], dtype=np.int64),  # This fails!\r\n        # "key": pd.Series([0, 1, 2], dtype=pd.UInt64Dtype()),  # This also fails!\r\n        # "key": pd.Series([0, 1, 2], dtype=pd.Int64Dtype()),  # This works!\r\n        "val2": pd.Series(["d", "e", "f"]),\r\n    }\r\n)\r\nprint(pd.merge(null_keys, non_null_keys, how="left", on="key").to_markdown())\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nIf you try to merge two (or more, probably) objects, and all of the following are true\r\n- col1 is a nullable integer type (eg `pd.Int64Dtype()`)\r\n- col1 contains nulls\r\n- col2 is an integer type (either nullable eg `pd.Int64Dtype()` or non-nullable eg `np.int64`)\r\n- `col1.dtype != col2.dtype`\r\nthen the merge fails with:\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "test.py", line 20, in <module>\r\n    pd.merge(null_keys, non_null_keys, on="key")\r\n  File "/workspaces/pandas/pandas/core/reshape/merge.py", line 123, in merge\r\n    return op.get_result()\r\n  File "/workspaces/pandas/pandas/core/reshape/merge.py", line 717, in get_result\r\n    join_index, left_indexer, right_indexer = self._get_join_info()\r\n  File "/workspaces/pandas/pandas/core/reshape/merge.py", line 968, in _get_join_info\r\n    (left_indexer, right_indexer) = self._get_join_indexers()\r\n  File "/workspaces/pandas/pandas/core/reshape/merge.py", line 942, in _get_join_indexers\r\n    return get_join_indexers(\r\n  File "/workspaces/pandas/pandas/core/reshape/merge.py", line 1497, in get_join_indexers\r\n    zipped = zip(*mapped)\r\n  File "/workspaces/pandas/pandas/core/reshape/merge.py", line 1494, in <genexpr>\r\n    _factorize_keys(left_keys[n], right_keys[n], sort=sort, how=how)\r\n  File "/workspaces/pandas/pandas/core/reshape/merge.py", line 2227, in _factorize_keys\r\n    lk = ensure_int64(np.asarray(lk))\r\n  File "pandas/_libs/algos_common_helper.pxi", line 81, in pandas._libs.algos.ensure_int64\r\n    return arr.astype(np.int64, copy=copy)\r\nTypeError: int() argument must be a string, a bytes-like object or a number, not \'NAType\'\r\n```\r\n\r\nHowever, if I change the `np.int64` dtype to `pd.Int64Dtype()` as well (eg both types are equal), then the merge works fine. (Note that changing both types to non-nullable types isn\'t applicable, because some of the keys are indeed null so that would be impossible). Also fails if one is `Int64` and the other is `UInt64`. Tested on main.\r\n\r\nThe offending code is probably [in `pandas/core/reshape/merge.py`, line 2227, in `_factorize_keys`](https://github.com/pandas-dev/pandas/blob/ec7543622a415301849bfa2f64243573c9fe5bee/pandas/core/reshape/merge.py#L2223), but I didn\'t dig any deeper than that.\r\n\r\n### Expected Behavior\r\n\r\nThe merge should act the same as when both keys are nullable and dtypes are equal (e.g. both `Int64Dtype`):\r\n|    | key   | val1   | val2   |\r\n|---:|:------|:-------|:-------|\r\n|  0 | 0     | a      | d      |\r\n|  1 | 1     | b      | e      |\r\n|  2 | nan  | c      | nan    |\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : ec7543622a415301849bfa2f64243573c9fe5bee\r\npython           : 3.8.12.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.10.47-linuxkit\r\nVersion          : #1 SMP Sat Jul 3 21:51: ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46798',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46798/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46798/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46798/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46798',
#   'id': 1207172802,
#   'node_id': 'PR_kwDOAA0YD842Xj3P',
#   'number': 46798,
#   'title': 'BUG: `DataFrameGroupBy.value_counts` includes non-observed categories of non-grouping columns',
#   'user': {'login': 'LucasG0',
#    'id': 44552904,
#    'node_id': 'MDQ6VXNlcjQ0NTUyOTA0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44552904?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LucasG0',
#    'html_url': 'https://github.com/LucasG0',
#    'followers_url': 'https://api.github.com/users/LucasG0/followers',
#    'following_url': 'https://api.github.com/users/LucasG0/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/LucasG0/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/LucasG0/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/LucasG0/subscriptions',
#    'organizations_url': 'https://api.github.com/users/LucasG0/orgs',
#    'repos_url': 'https://api.github.com/users/LucasG0/repos',
#    'events_url': 'https://api.github.com/users/LucasG0/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/LucasG0/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-18T15:40:37Z',
#   'updated_at': '2022-04-18T21:11:22Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46798',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46798',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46798.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46798.patch',
#    'merged_at': None},
#   'body': '- [X] closes #46357\r\n- [X] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [X] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [X] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46798/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46798/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46797',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46797/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46797/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46797/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46797',
#   'id': 1206612518,
#   'node_id': 'I_kwDOAA0YD85H63Im',
#   'number': 46797,
#   'title': 'BUG:  pandas.cut  doesnt respect to `precision=3` when  `include_lowest=True`',
#   'user': {'login': 'eromoe',
#    'id': 3938751,
#    'node_id': 'MDQ6VXNlcjM5Mzg3NTE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3938751?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eromoe',
#    'html_url': 'https://github.com/eromoe',
#    'followers_url': 'https://api.github.com/users/eromoe/followers',
#    'following_url': 'https://api.github.com/users/eromoe/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/eromoe/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/eromoe/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/eromoe/subscriptions',
#    'organizations_url': 'https://api.github.com/users/eromoe/orgs',
#    'repos_url': 'https://api.github.com/users/eromoe/repos',
#    'events_url': 'https://api.github.com/users/eromoe/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/eromoe/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-18T03:20:23Z',
#   'updated_at': '2022-04-18T03:20:23Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\na  = pd.Series(np.linspace(-0.9999999, 10, 200))\r\npd.cut(a, 10, retbins=True, include_lowest=True, precision=3)\n```\n\n\n### Issue Description\n\n![image](https://user-images.githubusercontent.com/3938751/163749171-8f834741-78da-4aba-80a3-3ac4ccc57953.png)\r\n\n\n### Expected Behavior\n\nlowest value should be precision=3\r\n\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 4bfe3d07b4858144c219b9346329027024102ab6\r\npython           : 3.8.8.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19041\r\nmachine          : AMD64\r\nprocessor        : AMD64 Family 25 Model 33 Stepping 0, AuthenticAMD\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : Chinese (Simplified)_China.936\r\n\r\npandas           : 1.4.2\r\nnumpy            : 1.19.5\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 22.0.4\r\nsetuptools       : 44.0.0\r\nCython           : 0.29.23\r\npytest           : 6.2.3\r\nhypothesis       : None\r\nsphinx           : 4.0.1\r\nblosc            : None\r\nfeather          : 0.4.1\r\nxlsxwriter       : 1.3.8\r\nlxml.etree       : 4.6.3\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.1\r\nIPython          : 7.22.0\r\npandas_datareader: None\r\nbs4              : 4.9.3\r\nbottleneck       : 1.3.2\r\nbrotli           : \r\nfastparquet      : None\r\nfsspec           : 2021.07.0\r\ngcsfs            : None\r\nmarkupsafe       : 2.1.1\r\nmatplotlib       : 3.3.4\r\nnumba            : 0.53.1\r\nnumexpr          : 2.7.3\r\nodfpy            : None\r\nopenpyxl         : 3.0.7\r\npandas_gbq       : None\r\npyarrow          : 7.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : 2021.07.0\r\nscipy            : 1.6.2\r\nsnappy           : None\r\nsqlalchemy       : 1.4.7\r\ntables           : 3.6.1\r\ntabulate         : 0.8.9\r\nxarray           : None\r\nxlrd             : 2.0.1\r\nxlwt             : 1.3.0\r\nzstandard        : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46797/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46797/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46793',
#   'id': 1206370745,
#   'node_id': 'I_kwDOAA0YD85H58G5',
#   'number': 46793,
#   'title': 'WEB: Use mambaforge for the getting started installation instructions?',
#   'user': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
#    'followers_url': 'https://api.github.com/users/datapythonista/followers',
#    'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#    'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#    'repos_url': 'https://api.github.com/users/datapythonista/repos',
#    'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 219960758,
#     'node_id': 'MDU6TGFiZWwyMTk5NjA3NTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Discussion',
#     'name': 'Needs Discussion',
#     'color': '207de5',
#     'default': False,
#     'description': 'Requires discussion from core team before further action'},
#    {'id': 717120670,
#     'node_id': 'MDU6TGFiZWw3MTcxMjA2NzA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/good%20first%20issue',
#     'name': 'good first issue',
#     'color': '0e8a16',
#     'default': True,
#     'description': None},
#    {'id': 1508144531,
#     'node_id': 'MDU6TGFiZWwxNTA4MTQ0NTMx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Web',
#     'name': 'Web',
#     'color': '23ef97',
#     'default': False,
#     'description': 'pandas website'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-17T13:07:21Z',
#   'updated_at': '2022-04-17T13:07:21Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "We've got [this page](https://pandas.pydata.org/getting_started.html) in our website, that is helping users set up a working environment to use pandas. With Anaconda moving to libmamba is probably fine to leave it as it is, but I'd personally use mambaforge in the page, which I think is probably a better choice of tool (smaller, only conda-forge channel, faster, a bit nicer UI). Does anyone think it's better to stay with Anaconda?",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46792',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46792/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46792/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46792/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46792',
#   'id': 1206301209,
#   'node_id': 'PR_kwDOAA0YD842Uu8E',
#   'number': 46792,
#   'title': 'DOC: Remove unused argument from resampler docstrings ',
#   'user': {'login': 'lorentzbao',
#    'id': 19342156,
#    'node_id': 'MDQ6VXNlcjE5MzQyMTU2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19342156?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lorentzbao',
#    'html_url': 'https://github.com/lorentzbao',
#    'followers_url': 'https://api.github.com/users/lorentzbao/followers',
#    'following_url': 'https://api.github.com/users/lorentzbao/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lorentzbao/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lorentzbao/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lorentzbao/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lorentzbao/orgs',
#    'repos_url': 'https://api.github.com/users/lorentzbao/repos',
#    'events_url': 'https://api.github.com/users/lorentzbao/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lorentzbao/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 74975453,
#     'node_id': 'MDU6TGFiZWw3NDk3NTQ1Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Resample',
#     'name': 'Resample',
#     'color': '207de5',
#     'default': False,
#     'description': 'resample method'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 6,
#   'created_at': '2022-04-17T07:06:15Z',
#   'updated_at': '2022-04-19T04:01:29Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46792',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46792',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46792.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46792.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #46442 (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nAfter examining the reported issue #46442, I found the issue exists in all the following docs.\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.core.resample.Resampler.sum.html\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.core.resample.Resampler.prod.html\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.core.resample.Resampler.min.html\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.core.resample.Resampler.max.html\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.core.resample.Resampler.first.html\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.core.resample.Resampler.last.html\r\n\r\nThe problem seems to be caused by the fact that the docstrings of `sum`, `prod`, `min`, `max`, `first`, `last` methods\r\nin the `Resampler` class borrow the `_groupby_agg_method_template` template from `GroupBy` class. I think one possible fix is\r\ncreating a `_resample_agg_method_template` and using this template to create docstrings for the methods mentioned above.\r\n\r\nI am a first-time contributor. Appreciate any suggestions and ideas for fixing this issue.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46792/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46792/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46791',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46791/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46791/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46791/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46791',
#   'id': 1206170540,
#   'node_id': 'PR_kwDOAA0YD842UW62',
#   'number': 46791,
#   'title': 'Change `mylen` function to account for NaN empty lists when exploding on multiple columns',
#   'user': {'login': 'ehariri',
#    'id': 21693509,
#    'node_id': 'MDQ6VXNlcjIxNjkzNTA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21693509?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ehariri',
#    'html_url': 'https://github.com/ehariri',
#    'followers_url': 'https://api.github.com/users/ehariri/followers',
#    'following_url': 'https://api.github.com/users/ehariri/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ehariri/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ehariri/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ehariri/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ehariri/orgs',
#    'repos_url': 'https://api.github.com/users/ehariri/repos',
#    'events_url': 'https://api.github.com/users/ehariri/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ehariri/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-04-16T17:13:00Z',
#   'updated_at': '2022-04-19T03:06:01Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46791',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46791',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46791.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46791.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46084 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46791/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46791/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46790',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46790/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46790/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46790/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46790',
#   'id': 1206164359,
#   'node_id': 'I_kwDOAA0YD85H5JuH',
#   'number': 46790,
#   'title': 'ENH: Add option for `bold_column_headers` to `to_latex()`',
#   'user': {'login': 'mosc9575',
#    'id': 68053396,
#    'node_id': 'MDQ6VXNlcjY4MDUzMzk2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68053396?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mosc9575',
#    'html_url': 'https://github.com/mosc9575',
#    'followers_url': 'https://api.github.com/users/mosc9575/followers',
#    'following_url': 'https://api.github.com/users/mosc9575/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mosc9575/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mosc9575/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mosc9575/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mosc9575/orgs',
#    'repos_url': 'https://api.github.com/users/mosc9575/repos',
#    'events_url': 'https://api.github.com/users/mosc9575/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mosc9575/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 251382258,
#     'node_id': 'MDU6TGFiZWwyNTEzODIyNTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20LaTeX',
#     'name': 'IO LaTeX',
#     'color': '006b75',
#     'default': False,
#     'description': 'to_latex'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2022-04-16T16:51:15Z',
#   'updated_at': '2022-04-18T07:21:23Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': "In the latest pandas version 1.4.2 there exists an option to enable bold rows but there isn't a similar option to do the same for the columns. It is something some users on [SO](https://stackoverflow.com/questions/71895146/pandas-to-latex-how-to-make-column-names-bold/71895635#71895635) were asking for and it seems very logical.\r\n\r\nThe example from the official documentation with `bold_rows=True` and `bold_column_headers=True` should lead to the following example.\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame(\r\n    dict(name=['Raphael', 'Donatello'],\r\n         mask=['red', 'purple'],\r\n         weapon=['sai', 'bo staff']\r\n        )\r\n)\r\nresult= df.to_latex(bold_rows=True, bold_column_headers=True)\r\n\r\n>>> result\r\n\\begin{tabular}{llll}\r\n\\toprule\r\n{} &       \\textbf{name} &    \\textbf{mask} &    \\textbf{weapon} \\\\\r\n\\midrule\r\n\\textbf{0} &    Raphael &     red &       sai \\\\\r\n\\textbf{1} &  Donatello &  purple &  bo staff \\\\\r\n\\bottomrule\r\n\\end{tabular}\r\n\r\n```\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46790/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46790/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46789',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46789/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46789/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46789/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46789',
#   'id': 1206141718,
#   'node_id': 'PR_kwDOAA0YD842UTSU',
#   'number': 46789,
#   'title': 'BUG: .fillna(-1) does not work in pd.eval',
#   'user': {'login': 'shyamsantoki',
#    'id': 56479219,
#    'node_id': 'MDQ6VXNlcjU2NDc5MjE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56479219?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shyamsantoki',
#    'html_url': 'https://github.com/shyamsantoki',
#    'followers_url': 'https://api.github.com/users/shyamsantoki/followers',
#    'following_url': 'https://api.github.com/users/shyamsantoki/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shyamsantoki/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shyamsantoki/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shyamsantoki/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shyamsantoki/orgs',
#    'repos_url': 'https://api.github.com/users/shyamsantoki/repos',
#    'events_url': 'https://api.github.com/users/shyamsantoki/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shyamsantoki/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-16T15:33:57Z',
#   'updated_at': '2022-04-17T17:16:14Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46789',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46789',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46789.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46789.patch',
#    'merged_at': None},
#   'body': 'Adding ```self.value``` resolves the issue #46471\r\n\r\n- [x] closes #46471\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46789/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46789/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46786',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46786/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46786/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46786/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46786',
#   'id': 1205872267,
#   'node_id': 'PR_kwDOAA0YD842TiuU',
#   'number': 46786,
#   'title': 'TYP: CallableDynamicDoc',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-04-15T20:34:45Z',
#   'updated_at': '2022-04-15T20:35:48Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46786',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46786',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46786.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46786.patch',
#    'merged_at': None},
#   'body': "The more tricky parts of #46698.\r\n\r\nAdding type annotations to `CallableDynamicDoc` seems to uncover multiple missing type annotations. I'm not very confident in some of the new pyi files (types for cython/c functions).",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46786/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46786/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46784',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46784/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46784/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46784/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46784',
#   'id': 1205765682,
#   'node_id': 'PR_kwDOAA0YD842TO4h',
#   'number': 46784,
#   'title': 'ENH: Added Index param to to_dict like in to_json #46398',
#   'user': {'login': 'vruthik',
#    'id': 59946643,
#    'node_id': 'MDQ6VXNlcjU5OTQ2NjQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59946643?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vruthik',
#    'html_url': 'https://github.com/vruthik',
#    'followers_url': 'https://api.github.com/users/vruthik/followers',
#    'following_url': 'https://api.github.com/users/vruthik/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/vruthik/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/vruthik/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/vruthik/subscriptions',
#    'organizations_url': 'https://api.github.com/users/vruthik/orgs',
#    'repos_url': 'https://api.github.com/users/vruthik/repos',
#    'events_url': 'https://api.github.com/users/vruthik/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/vruthik/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-15T18:00:03Z',
#   'updated_at': '2022-04-15T20:49:32Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46784',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46784',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46784.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46784.patch',
#    'merged_at': None},
#   'body': '- [X] closes #46398 \r\n- [X] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [X] Added an entry in the latest `doc/source/whatsnew/v1.5.0.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46784/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46784/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46783',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46783/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46783/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46783/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46783',
#   'id': 1205740295,
#   'node_id': 'I_kwDOAA0YD85H3iMH',
#   'number': 46783,
#   'title': 'BUG: `dropna=False` not respected for groupby aggs on result of concatenated dataframes',
#   'user': {'login': 'charlesbluca',
#    'id': 20627856,
#    'node_id': 'MDQ6VXNlcjIwNjI3ODU2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20627856?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/charlesbluca',
#    'html_url': 'https://github.com/charlesbluca',
#    'followers_url': 'https://api.github.com/users/charlesbluca/followers',
#    'following_url': 'https://api.github.com/users/charlesbluca/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/charlesbluca/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/charlesbluca/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/charlesbluca/subscriptions',
#    'organizations_url': 'https://api.github.com/users/charlesbluca/orgs',
#    'repos_url': 'https://api.github.com/users/charlesbluca/repos',
#    'events_url': 'https://api.github.com/users/charlesbluca/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/charlesbluca/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 2822342,
#     'node_id': 'MDU6TGFiZWwyODIyMzQy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Missing-data',
#     'name': 'Missing-data',
#     'color': 'd7e102',
#     'default': False,
#     'description': 'np.nan, pd.NaT, pd.NA, dropna, isnull, interpolate'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 989,
#    'closed_issues': 840,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2022-04-18T00:58:07Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2022-04-15T17:22:25Z',
#   'updated_at': '2022-04-15T21:57:07Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
# ...
#    'following_url': 'https://api.github.com/users/cmjcharlton/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cmjcharlton/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cmjcharlton/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cmjcharlton/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cmjcharlton/orgs',
#    'repos_url': 'https://api.github.com/users/cmjcharlton/repos',
#    'events_url': 'https://api.github.com/users/cmjcharlton/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cmjcharlton/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 104865385,
#     'node_id': 'MDU6TGFiZWwxMDQ4NjUzODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Stata',
#     'name': 'IO Stata',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_stata, to_stata'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-12T11:40:25Z',
#   'updated_at': '2022-04-12T12:21:04Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\ndf = pd.DataFrame(\r\n    {\r\n        "fully_labelled": [1, 2, 3, 3, 1],\r\n    }\r\n)\r\n\r\nvalue_labels = {\r\n    "fully_labelled": {1: "one", 2: "two", 3: "three"},\r\n}\r\n\r\ndf.to_stata("test.dta", value_labels = value_labels, version = 118)\n```\n\n\n### Issue Description\n\nWhen attempting to open the file created by the above code in Stata 17 MP the following error message is returned:\r\n\r\n```\r\n.dta file corrupt\r\n    The file unexpectedly ended before it should have.\r\nr(612);\r\n```\r\n\r\nThis also occurs if version is set to 119.\r\n\r\nI believe that this is because the space allocated for the label name is 33 bytes instead of the required 129, as the encoding is set to latin-1 by default and has not been changed to utf-8 based on the specified version.\r\n\r\nIf I change the line:\r\n```python\r\nsvl = StataNonCatValueLabel(colname, labels)\r\n```\r\n\r\nto:\r\n```python\r\nsvl = StataNonCatValueLabel(colname, labels, self._encoding)\r\n```\r\n\r\nin the function ```_prepare_non_cat_value_labels()``` in /pandas/io/stata.py\r\n\r\nand run the example again then the file created appears to open successfully with the value labels intact.\r\n\n\n### Expected Behavior\n\nNo error message is returned, the data is loaded into Stata and the value labels are correctly applied.\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 4bfe3d07b4858144c219b9346329027024102ab6\r\npython           : 3.10.4.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 2012ServerR2\r\nVersion          : 6.3.9600\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 63 Stepping 2, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United Kingdom.1252\r\n\r\npandas           : 1.4.2\r\nnumpy            : 1.21.5\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\npip              : 22.0.4\r\nsetuptools       : 62.1.0\r\nCython           : 0.29.28\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.8.0\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.1\r\nIPython          : 8.2.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmarkupsafe       : 2.1.1\r\nmatplotlib       : 3.5.1\r\nnumba            : 0.55.1\r\nnumexpr          : 2.8.1\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.8.0\r\nsnappy           : None\r\nsqlalchemy       : 1.4.35\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46750/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46750/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46747',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46747/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46747/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46747/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46747',
#   'id': 1201449320,
#   'node_id': 'I_kwDOAA0YD85HnKlo',
#   'number': 46747,
#   'title': 'ENH: Always write directly to output in `to_pickle`',
#   'user': {'login': 'jakirkham',
#    'id': 3019665,
#    'node_id': 'MDQ6VXNlcjMwMTk2NjU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3019665?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jakirkham',
#    'html_url': 'https://github.com/jakirkham',
#    'followers_url': 'https://api.github.com/users/jakirkham/followers',
#    'following_url': 'https://api.github.com/users/jakirkham/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jakirkham/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jakirkham/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jakirkham/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jakirkham/orgs',
#    'repos_url': 'https://api.github.com/users/jakirkham/repos',
#    'events_url': 'https://api.github.com/users/jakirkham/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jakirkham/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1625435109,
#     'node_id': 'MDU6TGFiZWwxNjI1NDM1MTA5',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Pickle',
#     'name': 'IO Pickle',
#     'color': '6c1cdb',
#     'default': False,
#     'description': 'read_pickle, to_pickle'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-12T08:49:22Z',
#   'updated_at': '2022-04-15T22:25:11Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "#### Is your feature request related to a problem?\r\n\r\nCurrently `to_pickle` has the following code to workaround issue ( https://github.com/pandas-dev/pandas/issues/39002 ). The result is an extra in-memory copy with pickle protocol 5 for some formats.\r\n\r\nhttps://github.com/pandas-dev/pandas/blob/c90294db40cd48fca7fbec5fa419b46a4b4768a1/pandas/io/pickle.py#L104-L109\r\n\r\n#### Describe the solution you'd like\r\n\r\nThe reason the file compressors fail is they often assume something that is `bytes`-like (though not as general as a `memoryview`). In particular they assume the data is 1-D contiguous and of `uint8` type. With `PickleBuffer`'s [`raw` method]( https://docs.python.org/3/library/pickle.html#pickle.PickleBuffer.raw ), it is pretty straightforward to construct a `memoryview` with this format. If the buffer is non-contiguous (not sure how often this would come up here), [`raw` will raise a `BufferError`]( https://github.com/python/cpython/blob/f4c03484da59049eb62a9bf7777b963e2267d187/Objects/picklebufobject.c#L156-L161 ). Though this can be mitigated by falling back to an in-memory copy if that exception occurs.\r\n\r\nGiven this, one option would be to wrap the `write` method of the compressor file objects that need this handling. For example the following would work on Python 3.8+.\r\n\r\n```python\r\nfrom bz2 import BZ2File as _BZ2File\r\nfrom pickle import PickleBuffer\r\n\r\n\r\nclass BZ2File(_BZ2File):\r\n    def write(self, b):\r\n        if isinstance(b, PickleBuffer):\r\n            try:\r\n                b = b.raw()  # coerce to 1-D `uint8` C-contiguous `memoryview` zero-copy\r\n            except BufferError:\r\n                b = bytes(b)  # perform in-memory copy if buffer is not contiguous\r\n        return super(BZ2File, self).write(b)\r\n```\r\n\r\nPotentially this could live alongside other custom file objects like [this one]( https://github.com/pandas-dev/pandas/blob/32999a1a45f2c4171b8ac5e97f5aa34b1956686c/pandas/io/common.py#L859 ) in `pandas.io.common` (albeit as private objects). Though maybe there are other places that could make sense.\r\n\r\n#### API breaking implications\r\n\r\nNA\r\n\r\nAlready when protocol 5 is set data with that protocol is written out in memory before writing to the file. This would only save the `memcpy` before writing to the file. Data written before and after this change should still be readable just the same.\r\n\r\n#### Describe alternatives you've considered\r\n\r\nUltimately it would be preferable to have this fixed upstream. In fact to some extent that has already happened ( https://github.com/python/cpython/issues/88605 ). However Python 3.8 is not covered, which is still supported by Pandas. Also if users are stuck on an earlier patch version of 3.9+, they may not have the fix. In these cases, it may make sense to have this workaround to provide the improved efficiency while protecting against this issue.\r\n\r\n#### Additional context\r\n\r\nNA (included above)",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46747/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46747/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46744',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46744/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46744/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46744/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46744',
#   'id': 1200431802,
#   'node_id': 'I_kwDOAA0YD85HjSK6',
#   'number': 46744,
#   'title': 'ENH: Support using repr() instead of str() to print non-numeric Series elements, especially strings',
#   'user': {'login': 'gwerbin',
#    'id': 5758789,
#    'node_id': 'MDQ6VXNlcjU3NTg3ODk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5758789?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gwerbin',
#    'html_url': 'https://github.com/gwerbin',
#    'followers_url': 'https://api.github.com/users/gwerbin/followers',
#    'following_url': 'https://api.github.com/users/gwerbin/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gwerbin/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gwerbin/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gwerbin/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gwerbin/orgs',
#    'repos_url': 'https://api.github.com/users/gwerbin/repos',
#    'events_url': 'https://api.github.com/users/gwerbin/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gwerbin/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 13101118,
#     'node_id': 'MDU6TGFiZWwxMzEwMTExOA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Output-Formatting',
#     'name': 'Output-Formatting',
#     'color': 'ededed',
#     'default': False,
#     'description': '__repr__ of pandas objects, to_string'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-04-11T19:24:49Z',
#   'updated_at': '2022-04-12T17:36:57Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "#### Is your feature request related to a problem?\r\n\r\nSometimes, it is useful for debugging to be able to see the contents of a Series with `repr()` instead of `str()` applied to each element.\r\n\r\nSpecifically with strings, it is often useful to see non-ASCII Unicode characters escaped, and to see the surrouning quotation marks, to detect whitespace at the start and end.\r\n\r\nAnother use case might be some situation where you have other nontrivial `object`s in a Series, and their `str` representations are somehow less useful than their `repr` representations.\r\n\r\nFor example, `print(pd.Series(['a', 'b', 'c'], dtype='string'))` yields:\r\n```\r\n0    a\r\n1    b\r\n2    c\r\ndtype: string\r\n```\r\n\r\nBut it would be helpful if it could yield:\r\n```\r\n0    'a'\r\n1    'b'\r\n2    'c'\r\ndtype: string\r\n```\r\n\r\n#### Describe the solution you'd like\r\n\r\nOne possibility is a new module option, maybe `display.string_as_repr` (just for strings) or `display.print_as_repr` (for all non-numeric entries), to enable this behavior.\r\n\r\n#### API breaking implications\r\n\r\nNone that I know of.\r\n\r\n#### Describe alternatives you've considered\r\n\r\nYou could use `.apply(repr)` or similar, to see this output in an ad-hoc way.\r\n\r\n#### Additional context\r\n\r\nThis was originally a StackOverflow question: <https://stackoverflow.com/q/71832297/2954547>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46744/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46744/timeline',
#   'performed_via_github_app': None}]

# %%
len(data1)
# Out:
# 30

# %%
data1[0]['user']['id']
# Out:
# 10820686

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 10820686
# 44552904
# 3938751
# 10058240
# 19342156
# 21693509
# 68053396
# 56479219
# 6618166
# 59946643
# 20627856
# 77794567
# 13159005
# 10647082
# 34522496
# 4476168
# 11664259
# 15113894
# 31669
# 18078278
# 5351947
# 23336875
# 15113894
# 3236794
# 5758789
# 3211163
# 3211163
# 90400333
# 3019665
# 5758789

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46799',
#   'id': 1207499980,
#   'node_id': 'I_kwDOAA0YD85H-PzM',
#   'number': 46799,
#   'title': 'BUG: Merge fails on nullable integer columns when dtypes are unequal',
#   'user': {'login': 'NickCrews',
#    'id': 10820686,
#    'node_id': 'MDQ6VXNlcjEwODIwNjg2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10820686?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NickCrews',
#    'html_url': 'https://github.com/NickCrews',
#    'followers_url': 'https://api.github.com/users/NickCrews/followers',
#    'following_url': 'https://api.github.com/users/NickCrews/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/NickCrews/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/NickCrews/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/NickCrews/subscriptions',
#    'organizations_url': 'https://api.github.com/users/NickCrews/orgs',
#    'repos_url': 'https://api.github.com/users/NickCrews/repos',
#    'events_url': 'https://api.github.com/users/NickCrews/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/NickCrews/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-18T22:09:52Z',
#   'updated_at': '2022-04-18T22:21:14Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport numpy as np\r\nimport pandas as pd\r\n\r\nnull_keys = pd.DataFrame(\r\n    {\r\n        "key": pd.Series([0, 1, pd.NA], dtype=pd.Int64Dtype()),\r\n        "val1": pd.Series(["a", "b", "c"]),\r\n    }\r\n)\r\nnon_null_keys = pd.DataFrame(\r\n    {\r\n        "key": pd.Series([0, 1, 2], dtype=np.int64),  # This fails!\r\n        # "key": pd.Series([0, 1, 2], dtype=pd.UInt64Dtype()),  # This also fails!\r\n        # "key": pd.Series([0, 1, 2], dtype=pd.Int64Dtype()),  # This works!\r\n        "val2": pd.Series(["d", "e", "f"]),\r\n    }\r\n)\r\nprint(pd.merge(null_keys, non_null_keys, how="left", on="key").to_markdown())\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nIf you try to merge two (or more, probably) objects, and all of the following are true\r\n- col1 is a nullable integer type (eg `pd.Int64Dtype()`)\r\n- col1 contains nulls\r\n- col2 is an integer type (either nullable eg `pd.Int64Dtype()` or non-nullable eg `np.int64`)\r\n- `col1.dtype != col2.dtype`\r\nthen the merge fails with:\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "test.py", line 20, in <module>\r\n    pd.merge(null_keys, non_null_keys, on="key")\r\n  File "/workspaces/pandas/pandas/core/reshape/merge.py", line 123, in merge\r\n    return op.get_result()\r\n  File "/workspaces/pandas/pandas/core/reshape/merge.py", line 717, in get_result\r\n    join_index, left_indexer, right_indexer = self._get_join_info()\r\n  File "/workspaces/pandas/pandas/core/reshape/merge.py", line 968, in _get_join_info\r\n    (left_indexer, right_indexer) = self._get_join_indexers()\r\n  File "/workspaces/pandas/pandas/core/reshape/merge.py", line 942, in _get_join_indexers\r\n    return get_join_indexers(\r\n  File "/workspaces/pandas/pandas/core/reshape/merge.py", line 1497, in get_join_indexers\r\n    zipped = zip(*mapped)\r\n  File "/workspaces/pandas/pandas/core/reshape/merge.py", line 1494, in <genexpr>\r\n    _factorize_keys(left_keys[n], right_keys[n], sort=sort, how=how)\r\n  File "/workspaces/pandas/pandas/core/reshape/merge.py", line 2227, in _factorize_keys\r\n    lk = ensure_int64(np.asarray(lk))\r\n  File "pandas/_libs/algos_common_helper.pxi", line 81, in pandas._libs.algos.ensure_int64\r\n    return arr.astype(np.int64, copy=copy)\r\nTypeError: int() argument must be a string, a bytes-like object or a number, not \'NAType\'\r\n```\r\n\r\nHowever, if I change the `np.int64` dtype to `pd.Int64Dtype()` as well (eg both types are equal), then the merge works fine. (Note that changing both types to non-nullable types isn\'t applicable, because some of the keys are indeed null so that would be impossible). Also fails if one is `Int64` and the other is `UInt64`. Tested on main.\r\n\r\nThe offending code is probably [in `pandas/core/reshape/merge.py`, line 2227, in `_factorize_keys`](https://github.com/pandas-dev/pandas/blob/ec7543622a415301849bfa2f64243573c9fe5bee/pandas/core/reshape/merge.py#L2223), but I didn\'t dig any deeper than that.\r\n\r\n### Expected Behavior\r\n\r\nThe merge should act the same as when both keys are nullable and dtypes are equal (e.g. both `Int64Dtype`):\r\n|    | key   | val1   | val2   |\r\n|---:|:------|:-------|:-------|\r\n|  0 | 0     | a      | d      |\r\n|  1 | 1     | b      | e      |\r\n|  2 | nan  | c      | nan    |\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : ec7543622a415301849bfa2f64243573c9fe5bee\r\npython           : 3.8.12.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.10.47-linuxkit\r\nVersion          : #1 SMP Sat Jul 3 21:51: ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46799/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46798',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46798/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46798/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46798/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46798',
#   'id': 1207172802,
#   'node_id': 'PR_kwDOAA0YD842Xj3P',
#   'number': 46798,
#   'title': 'BUG: `DataFrameGroupBy.value_counts` includes non-observed categories of non-grouping columns',
#   'user': {'login': 'LucasG0',
#    'id': 44552904,
#    'node_id': 'MDQ6VXNlcjQ0NTUyOTA0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44552904?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LucasG0',
#    'html_url': 'https://github.com/LucasG0',
#    'followers_url': 'https://api.github.com/users/LucasG0/followers',
#    'following_url': 'https://api.github.com/users/LucasG0/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/LucasG0/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/LucasG0/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/LucasG0/subscriptions',
#    'organizations_url': 'https://api.github.com/users/LucasG0/orgs',
#    'repos_url': 'https://api.github.com/users/LucasG0/repos',
#    'events_url': 'https://api.github.com/users/LucasG0/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/LucasG0/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-18T15:40:37Z',
#   'updated_at': '2022-04-18T21:11:22Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46798',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46798',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46798.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46798.patch',
#    'merged_at': None},
#   'body': '- [X] closes #46357\r\n- [X] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [X] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [X] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46798/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46798/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46797',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46797/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46797/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46797/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46797',
#   'id': 1206612518,
#   'node_id': 'I_kwDOAA0YD85H63Im',
#   'number': 46797,
#   'title': 'BUG:  pandas.cut  doesnt respect to `precision=3` when  `include_lowest=True`',
#   'user': {'login': 'eromoe',
#    'id': 3938751,
#    'node_id': 'MDQ6VXNlcjM5Mzg3NTE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3938751?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eromoe',
#    'html_url': 'https://github.com/eromoe',
#    'followers_url': 'https://api.github.com/users/eromoe/followers',
#    'following_url': 'https://api.github.com/users/eromoe/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/eromoe/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/eromoe/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/eromoe/subscriptions',
#    'organizations_url': 'https://api.github.com/users/eromoe/orgs',
#    'repos_url': 'https://api.github.com/users/eromoe/repos',
#    'events_url': 'https://api.github.com/users/eromoe/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/eromoe/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-18T03:20:23Z',
#   'updated_at': '2022-04-18T03:20:23Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\na  = pd.Series(np.linspace(-0.9999999, 10, 200))\r\npd.cut(a, 10, retbins=True, include_lowest=True, precision=3)\n```\n\n\n### Issue Description\n\n![image](https://user-images.githubusercontent.com/3938751/163749171-8f834741-78da-4aba-80a3-3ac4ccc57953.png)\r\n\n\n### Expected Behavior\n\nlowest value should be precision=3\r\n\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 4bfe3d07b4858144c219b9346329027024102ab6\r\npython           : 3.8.8.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19041\r\nmachine          : AMD64\r\nprocessor        : AMD64 Family 25 Model 33 Stepping 0, AuthenticAMD\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : Chinese (Simplified)_China.936\r\n\r\npandas           : 1.4.2\r\nnumpy            : 1.19.5\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 22.0.4\r\nsetuptools       : 44.0.0\r\nCython           : 0.29.23\r\npytest           : 6.2.3\r\nhypothesis       : None\r\nsphinx           : 4.0.1\r\nblosc            : None\r\nfeather          : 0.4.1\r\nxlsxwriter       : 1.3.8\r\nlxml.etree       : 4.6.3\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.1\r\nIPython          : 7.22.0\r\npandas_datareader: None\r\nbs4              : 4.9.3\r\nbottleneck       : 1.3.2\r\nbrotli           : \r\nfastparquet      : None\r\nfsspec           : 2021.07.0\r\ngcsfs            : None\r\nmarkupsafe       : 2.1.1\r\nmatplotlib       : 3.3.4\r\nnumba            : 0.53.1\r\nnumexpr          : 2.7.3\r\nodfpy            : None\r\nopenpyxl         : 3.0.7\r\npandas_gbq       : None\r\npyarrow          : 7.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : 2021.07.0\r\nscipy            : 1.6.2\r\nsnappy           : None\r\nsqlalchemy       : 1.4.7\r\ntables           : 3.6.1\r\ntabulate         : 0.8.9\r\nxarray           : None\r\nxlrd             : 2.0.1\r\nxlwt             : 1.3.0\r\nzstandard        : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46797/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46797/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46793',
#   'id': 1206370745,
#   'node_id': 'I_kwDOAA0YD85H58G5',
#   'number': 46793,
#   'title': 'WEB: Use mambaforge for the getting started installation instructions?',
#   'user': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
#    'followers_url': 'https://api.github.com/users/datapythonista/followers',
#    'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#    'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#    'repos_url': 'https://api.github.com/users/datapythonista/repos',
#    'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 219960758,
#     'node_id': 'MDU6TGFiZWwyMTk5NjA3NTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Discussion',
#     'name': 'Needs Discussion',
#     'color': '207de5',
#     'default': False,
#     'description': 'Requires discussion from core team before further action'},
#    {'id': 717120670,
#     'node_id': 'MDU6TGFiZWw3MTcxMjA2NzA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/good%20first%20issue',
#     'name': 'good first issue',
#     'color': '0e8a16',
#     'default': True,
#     'description': None},
#    {'id': 1508144531,
#     'node_id': 'MDU6TGFiZWwxNTA4MTQ0NTMx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Web',
#     'name': 'Web',
#     'color': '23ef97',
#     'default': False,
#     'description': 'pandas website'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-17T13:07:21Z',
#   'updated_at': '2022-04-17T13:07:21Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "We've got [this page](https://pandas.pydata.org/getting_started.html) in our website, that is helping users set up a working environment to use pandas. With Anaconda moving to libmamba is probably fine to leave it as it is, but I'd personally use mambaforge in the page, which I think is probably a better choice of tool (smaller, only conda-forge channel, faster, a bit nicer UI). Does anyone think it's better to stay with Anaconda?",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46793/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46792',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46792/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46792/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46792/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46792',
#   'id': 1206301209,
#   'node_id': 'PR_kwDOAA0YD842Uu8E',
#   'number': 46792,
#   'title': 'DOC: Remove unused argument from resampler docstrings ',
#   'user': {'login': 'lorentzbao',
#    'id': 19342156,
#    'node_id': 'MDQ6VXNlcjE5MzQyMTU2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19342156?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lorentzbao',
#    'html_url': 'https://github.com/lorentzbao',
#    'followers_url': 'https://api.github.com/users/lorentzbao/followers',
#    'following_url': 'https://api.github.com/users/lorentzbao/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lorentzbao/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lorentzbao/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lorentzbao/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lorentzbao/orgs',
#    'repos_url': 'https://api.github.com/users/lorentzbao/repos',
#    'events_url': 'https://api.github.com/users/lorentzbao/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lorentzbao/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 74975453,
#     'node_id': 'MDU6TGFiZWw3NDk3NTQ1Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Resample',
#     'name': 'Resample',
#     'color': '207de5',
#     'default': False,
#     'description': 'resample method'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 6,
#   'created_at': '2022-04-17T07:06:15Z',
#   'updated_at': '2022-04-19T04:01:29Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46792',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46792',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46792.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46792.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #46442 (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nAfter examining the reported issue #46442, I found the issue exists in all the following docs.\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.core.resample.Resampler.sum.html\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.core.resample.Resampler.prod.html\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.core.resample.Resampler.min.html\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.core.resample.Resampler.max.html\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.core.resample.Resampler.first.html\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.core.resample.Resampler.last.html\r\n\r\nThe problem seems to be caused by the fact that the docstrings of `sum`, `prod`, `min`, `max`, `first`, `last` methods\r\nin the `Resampler` class borrow the `_groupby_agg_method_template` template from `GroupBy` class. I think one possible fix is\r\ncreating a `_resample_agg_method_template` and using this template to create docstrings for the methods mentioned above.\r\n\r\nI am a first-time contributor. Appreciate any suggestions and ideas for fixing this issue.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46792/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46792/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46791',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46791/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46791/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46791/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46791',
#   'id': 1206170540,
#   'node_id': 'PR_kwDOAA0YD842UW62',
#   'number': 46791,
#   'title': 'Change `mylen` function to account for NaN empty lists when exploding on multiple columns',
#   'user': {'login': 'ehariri',
#    'id': 21693509,
#    'node_id': 'MDQ6VXNlcjIxNjkzNTA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21693509?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ehariri',
#    'html_url': 'https://github.com/ehariri',
#    'followers_url': 'https://api.github.com/users/ehariri/followers',
#    'following_url': 'https://api.github.com/users/ehariri/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ehariri/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ehariri/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ehariri/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ehariri/orgs',
#    'repos_url': 'https://api.github.com/users/ehariri/repos',
#    'events_url': 'https://api.github.com/users/ehariri/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ehariri/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-04-16T17:13:00Z',
#   'updated_at': '2022-04-19T03:06:01Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46791',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46791',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46791.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46791.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46084 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46791/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46791/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46790',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46790/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46790/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46790/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46790',
#   'id': 1206164359,
#   'node_id': 'I_kwDOAA0YD85H5JuH',
#   'number': 46790,
#   'title': 'ENH: Add option for `bold_column_headers` to `to_latex()`',
#   'user': {'login': 'mosc9575',
#    'id': 68053396,
#    'node_id': 'MDQ6VXNlcjY4MDUzMzk2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68053396?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mosc9575',
#    'html_url': 'https://github.com/mosc9575',
#    'followers_url': 'https://api.github.com/users/mosc9575/followers',
#    'following_url': 'https://api.github.com/users/mosc9575/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mosc9575/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mosc9575/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mosc9575/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mosc9575/orgs',
#    'repos_url': 'https://api.github.com/users/mosc9575/repos',
#    'events_url': 'https://api.github.com/users/mosc9575/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mosc9575/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 251382258,
#     'node_id': 'MDU6TGFiZWwyNTEzODIyNTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20LaTeX',
#     'name': 'IO LaTeX',
#     'color': '006b75',
#     'default': False,
#     'description': 'to_latex'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2022-04-16T16:51:15Z',
#   'updated_at': '2022-04-18T07:21:23Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': "In the latest pandas version 1.4.2 there exists an option to enable bold rows but there isn't a similar option to do the same for the columns. It is something some users on [SO](https://stackoverflow.com/questions/71895146/pandas-to-latex-how-to-make-column-names-bold/71895635#71895635) were asking for and it seems very logical.\r\n\r\nThe example from the official documentation with `bold_rows=True` and `bold_column_headers=True` should lead to the following example.\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame(\r\n    dict(name=['Raphael', 'Donatello'],\r\n         mask=['red', 'purple'],\r\n         weapon=['sai', 'bo staff']\r\n        )\r\n)\r\nresult= df.to_latex(bold_rows=True, bold_column_headers=True)\r\n\r\n>>> result\r\n\\begin{tabular}{llll}\r\n\\toprule\r\n{} &       \\textbf{name} &    \\textbf{mask} &    \\textbf{weapon} \\\\\r\n\\midrule\r\n\\textbf{0} &    Raphael &     red &       sai \\\\\r\n\\textbf{1} &  Donatello &  purple &  bo staff \\\\\r\n\\bottomrule\r\n\\end{tabular}\r\n\r\n```\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46790/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46790/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46789',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46789/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46789/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46789/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46789',
#   'id': 1206141718,
#   'node_id': 'PR_kwDOAA0YD842UTSU',
#   'number': 46789,
#   'title': 'BUG: .fillna(-1) does not work in pd.eval',
#   'user': {'login': 'shyamsantoki',
#    'id': 56479219,
#    'node_id': 'MDQ6VXNlcjU2NDc5MjE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56479219?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shyamsantoki',
#    'html_url': 'https://github.com/shyamsantoki',
#    'followers_url': 'https://api.github.com/users/shyamsantoki/followers',
#    'following_url': 'https://api.github.com/users/shyamsantoki/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shyamsantoki/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shyamsantoki/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shyamsantoki/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shyamsantoki/orgs',
#    'repos_url': 'https://api.github.com/users/shyamsantoki/repos',
#    'events_url': 'https://api.github.com/users/shyamsantoki/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shyamsantoki/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-16T15:33:57Z',
#   'updated_at': '2022-04-17T17:16:14Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46789',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46789',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46789.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46789.patch',
#    'merged_at': None},
#   'body': 'Adding ```self.value``` resolves the issue #46471\r\n\r\n- [x] closes #46471\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46789/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46789/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46786',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46786/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46786/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46786/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46786',
#   'id': 1205872267,
#   'node_id': 'PR_kwDOAA0YD842TiuU',
#   'number': 46786,
#   'title': 'TYP: CallableDynamicDoc',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-04-15T20:34:45Z',
#   'updated_at': '2022-04-15T20:35:48Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46786',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46786',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46786.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46786.patch',
#    'merged_at': None},
#   'body': "The more tricky parts of #46698.\r\n\r\nAdding type annotations to `CallableDynamicDoc` seems to uncover multiple missing type annotations. I'm not very confident in some of the new pyi files (types for cython/c functions).",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46786/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46786/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46784',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46784/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46784/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46784/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46784',
#   'id': 1205765682,
#   'node_id': 'PR_kwDOAA0YD842TO4h',
#   'number': 46784,
#   'title': 'ENH: Added Index param to to_dict like in to_json #46398',
#   'user': {'login': 'vruthik',
#    'id': 59946643,
#    'node_id': 'MDQ6VXNlcjU5OTQ2NjQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59946643?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vruthik',
#    'html_url': 'https://github.com/vruthik',
#    'followers_url': 'https://api.github.com/users/vruthik/followers',
#    'following_url': 'https://api.github.com/users/vruthik/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/vruthik/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/vruthik/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/vruthik/subscriptions',
#    'organizations_url': 'https://api.github.com/users/vruthik/orgs',
#    'repos_url': 'https://api.github.com/users/vruthik/repos',
#    'events_url': 'https://api.github.com/users/vruthik/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/vruthik/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-15T18:00:03Z',
#   'updated_at': '2022-04-15T20:49:32Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46784',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46784',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46784.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46784.patch',
#    'merged_at': None},
#   'body': '- [X] closes #46398 \r\n- [X] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [X] Added an entry in the latest `doc/source/whatsnew/v1.5.0.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46784/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46784/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46783',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46783/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46783/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46783/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46783',
#   'id': 1205740295,
#   'node_id': 'I_kwDOAA0YD85H3iMH',
#   'number': 46783,
#   'title': 'BUG: `dropna=False` not respected for groupby aggs on result of concatenated dataframes',
#   'user': {'login': 'charlesbluca',
#    'id': 20627856,
#    'node_id': 'MDQ6VXNlcjIwNjI3ODU2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20627856?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/charlesbluca',
#    'html_url': 'https://github.com/charlesbluca',
#    'followers_url': 'https://api.github.com/users/charlesbluca/followers',
#    'following_url': 'https://api.github.com/users/charlesbluca/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/charlesbluca/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/charlesbluca/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/charlesbluca/subscriptions',
#    'organizations_url': 'https://api.github.com/users/charlesbluca/orgs',
#    'repos_url': 'https://api.github.com/users/charlesbluca/repos',
#    'events_url': 'https://api.github.com/users/charlesbluca/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/charlesbluca/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 2822342,
#     'node_id': 'MDU6TGFiZWwyODIyMzQy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Missing-data',
#     'name': 'Missing-data',
#     'color': 'd7e102',
#     'default': False,
#     'description': 'np.nan, pd.NaT, pd.NA, dropna, isnull, interpolate'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 989,
#    'closed_issues': 840,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2022-04-18T00:58:07Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2022-04-15T17:22:25Z',
#   'updated_at': '2022-04-15T21:57:07Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
# ...
#    'following_url': 'https://api.github.com/users/cmjcharlton/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cmjcharlton/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cmjcharlton/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cmjcharlton/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cmjcharlton/orgs',
#    'repos_url': 'https://api.github.com/users/cmjcharlton/repos',
#    'events_url': 'https://api.github.com/users/cmjcharlton/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cmjcharlton/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 104865385,
#     'node_id': 'MDU6TGFiZWwxMDQ4NjUzODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Stata',
#     'name': 'IO Stata',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_stata, to_stata'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-12T11:40:25Z',
#   'updated_at': '2022-04-12T12:21:04Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\ndf = pd.DataFrame(\r\n    {\r\n        "fully_labelled": [1, 2, 3, 3, 1],\r\n    }\r\n)\r\n\r\nvalue_labels = {\r\n    "fully_labelled": {1: "one", 2: "two", 3: "three"},\r\n}\r\n\r\ndf.to_stata("test.dta", value_labels = value_labels, version = 118)\n```\n\n\n### Issue Description\n\nWhen attempting to open the file created by the above code in Stata 17 MP the following error message is returned:\r\n\r\n```\r\n.dta file corrupt\r\n    The file unexpectedly ended before it should have.\r\nr(612);\r\n```\r\n\r\nThis also occurs if version is set to 119.\r\n\r\nI believe that this is because the space allocated for the label name is 33 bytes instead of the required 129, as the encoding is set to latin-1 by default and has not been changed to utf-8 based on the specified version.\r\n\r\nIf I change the line:\r\n```python\r\nsvl = StataNonCatValueLabel(colname, labels)\r\n```\r\n\r\nto:\r\n```python\r\nsvl = StataNonCatValueLabel(colname, labels, self._encoding)\r\n```\r\n\r\nin the function ```_prepare_non_cat_value_labels()``` in /pandas/io/stata.py\r\n\r\nand run the example again then the file created appears to open successfully with the value labels intact.\r\n\n\n### Expected Behavior\n\nNo error message is returned, the data is loaded into Stata and the value labels are correctly applied.\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 4bfe3d07b4858144c219b9346329027024102ab6\r\npython           : 3.10.4.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 2012ServerR2\r\nVersion          : 6.3.9600\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 63 Stepping 2, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United Kingdom.1252\r\n\r\npandas           : 1.4.2\r\nnumpy            : 1.21.5\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\npip              : 22.0.4\r\nsetuptools       : 62.1.0\r\nCython           : 0.29.28\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.8.0\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.1\r\nIPython          : 8.2.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmarkupsafe       : 2.1.1\r\nmatplotlib       : 3.5.1\r\nnumba            : 0.55.1\r\nnumexpr          : 2.8.1\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.8.0\r\nsnappy           : None\r\nsqlalchemy       : 1.4.35\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46750/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46750/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46747',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46747/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46747/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46747/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46747',
#   'id': 1201449320,
#   'node_id': 'I_kwDOAA0YD85HnKlo',
#   'number': 46747,
#   'title': 'ENH: Always write directly to output in `to_pickle`',
#   'user': {'login': 'jakirkham',
#    'id': 3019665,
#    'node_id': 'MDQ6VXNlcjMwMTk2NjU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3019665?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jakirkham',
#    'html_url': 'https://github.com/jakirkham',
#    'followers_url': 'https://api.github.com/users/jakirkham/followers',
#    'following_url': 'https://api.github.com/users/jakirkham/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jakirkham/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jakirkham/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jakirkham/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jakirkham/orgs',
#    'repos_url': 'https://api.github.com/users/jakirkham/repos',
#    'events_url': 'https://api.github.com/users/jakirkham/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jakirkham/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1625435109,
#     'node_id': 'MDU6TGFiZWwxNjI1NDM1MTA5',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Pickle',
#     'name': 'IO Pickle',
#     'color': '6c1cdb',
#     'default': False,
#     'description': 'read_pickle, to_pickle'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-12T08:49:22Z',
#   'updated_at': '2022-04-15T22:25:11Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "#### Is your feature request related to a problem?\r\n\r\nCurrently `to_pickle` has the following code to workaround issue ( https://github.com/pandas-dev/pandas/issues/39002 ). The result is an extra in-memory copy with pickle protocol 5 for some formats.\r\n\r\nhttps://github.com/pandas-dev/pandas/blob/c90294db40cd48fca7fbec5fa419b46a4b4768a1/pandas/io/pickle.py#L104-L109\r\n\r\n#### Describe the solution you'd like\r\n\r\nThe reason the file compressors fail is they often assume something that is `bytes`-like (though not as general as a `memoryview`). In particular they assume the data is 1-D contiguous and of `uint8` type. With `PickleBuffer`'s [`raw` method]( https://docs.python.org/3/library/pickle.html#pickle.PickleBuffer.raw ), it is pretty straightforward to construct a `memoryview` with this format. If the buffer is non-contiguous (not sure how often this would come up here), [`raw` will raise a `BufferError`]( https://github.com/python/cpython/blob/f4c03484da59049eb62a9bf7777b963e2267d187/Objects/picklebufobject.c#L156-L161 ). Though this can be mitigated by falling back to an in-memory copy if that exception occurs.\r\n\r\nGiven this, one option would be to wrap the `write` method of the compressor file objects that need this handling. For example the following would work on Python 3.8+.\r\n\r\n```python\r\nfrom bz2 import BZ2File as _BZ2File\r\nfrom pickle import PickleBuffer\r\n\r\n\r\nclass BZ2File(_BZ2File):\r\n    def write(self, b):\r\n        if isinstance(b, PickleBuffer):\r\n            try:\r\n                b = b.raw()  # coerce to 1-D `uint8` C-contiguous `memoryview` zero-copy\r\n            except BufferError:\r\n                b = bytes(b)  # perform in-memory copy if buffer is not contiguous\r\n        return super(BZ2File, self).write(b)\r\n```\r\n\r\nPotentially this could live alongside other custom file objects like [this one]( https://github.com/pandas-dev/pandas/blob/32999a1a45f2c4171b8ac5e97f5aa34b1956686c/pandas/io/common.py#L859 ) in `pandas.io.common` (albeit as private objects). Though maybe there are other places that could make sense.\r\n\r\n#### API breaking implications\r\n\r\nNA\r\n\r\nAlready when protocol 5 is set data with that protocol is written out in memory before writing to the file. This would only save the `memcpy` before writing to the file. Data written before and after this change should still be readable just the same.\r\n\r\n#### Describe alternatives you've considered\r\n\r\nUltimately it would be preferable to have this fixed upstream. In fact to some extent that has already happened ( https://github.com/python/cpython/issues/88605 ). However Python 3.8 is not covered, which is still supported by Pandas. Also if users are stuck on an earlier patch version of 3.9+, they may not have the fix. In these cases, it may make sense to have this workaround to provide the improved efficiency while protecting against this issue.\r\n\r\n#### Additional context\r\n\r\nNA (included above)",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46747/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46747/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46744',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46744/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46744/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46744/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46744',
#   'id': 1200431802,
#   'node_id': 'I_kwDOAA0YD85HjSK6',
#   'number': 46744,
#   'title': 'ENH: Support using repr() instead of str() to print non-numeric Series elements, especially strings',
#   'user': {'login': 'gwerbin',
#    'id': 5758789,
#    'node_id': 'MDQ6VXNlcjU3NTg3ODk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5758789?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gwerbin',
#    'html_url': 'https://github.com/gwerbin',
#    'followers_url': 'https://api.github.com/users/gwerbin/followers',
#    'following_url': 'https://api.github.com/users/gwerbin/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gwerbin/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gwerbin/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gwerbin/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gwerbin/orgs',
#    'repos_url': 'https://api.github.com/users/gwerbin/repos',
#    'events_url': 'https://api.github.com/users/gwerbin/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gwerbin/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 13101118,
#     'node_id': 'MDU6TGFiZWwxMzEwMTExOA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Output-Formatting',
#     'name': 'Output-Formatting',
#     'color': 'ededed',
#     'default': False,
#     'description': '__repr__ of pandas objects, to_string'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-04-11T19:24:49Z',
#   'updated_at': '2022-04-12T17:36:57Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "#### Is your feature request related to a problem?\r\n\r\nSometimes, it is useful for debugging to be able to see the contents of a Series with `repr()` instead of `str()` applied to each element.\r\n\r\nSpecifically with strings, it is often useful to see non-ASCII Unicode characters escaped, and to see the surrouning quotation marks, to detect whitespace at the start and end.\r\n\r\nAnother use case might be some situation where you have other nontrivial `object`s in a Series, and their `str` representations are somehow less useful than their `repr` representations.\r\n\r\nFor example, `print(pd.Series(['a', 'b', 'c'], dtype='string'))` yields:\r\n```\r\n0    a\r\n1    b\r\n2    c\r\ndtype: string\r\n```\r\n\r\nBut it would be helpful if it could yield:\r\n```\r\n0    'a'\r\n1    'b'\r\n2    'c'\r\ndtype: string\r\n```\r\n\r\n#### Describe the solution you'd like\r\n\r\nOne possibility is a new module option, maybe `display.string_as_repr` (just for strings) or `display.print_as_repr` (for all non-numeric entries), to enable this behavior.\r\n\r\n#### API breaking implications\r\n\r\nNone that I know of.\r\n\r\n#### Describe alternatives you've considered\r\n\r\nYou could use `.apply(repr)` or similar, to see this output in an ad-hoc way.\r\n\r\n#### Additional context\r\n\r\nThis was originally a StackOverflow question: <https://stackoverflow.com/q/71832297/2954547>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46744/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46744/timeline',
#   'performed_via_github_app': None}]

# %%
df2=pd.DataFrame(data1,columns=['id','url','repository_url','labels_url','user'])

# %%
df2
# Out:
#             id                                                url  \
# 0   1207499980  https://api.github.com/repos/pandas-dev/pandas...
# 1   1207172802  https://api.github.com/repos/pandas-dev/pandas...
# 2   1206612518  https://api.github.com/repos/pandas-dev/pandas...
# 3   1206370745  https://api.github.com/repos/pandas-dev/pandas...
# 4   1206301209  https://api.github.com/repos/pandas-dev/pandas...
# 5   1206170540  https://api.github.com/repos/pandas-dev/pandas...
# 6   1206164359  https://api.github.com/repos/pandas-dev/pandas...
# 7   1206141718  https://api.github.com/repos/pandas-dev/pandas...
# 8   1205872267  https://api.github.com/repos/pandas-dev/pandas...
# 9   1205765682  https://api.github.com/repos/pandas-dev/pandas...
# 10  1205740295  https://api.github.com/repos/pandas-dev/pandas...
# 11  1204912401  https://api.github.com/repos/pandas-dev/pandas...
# 12  1204378879  https://api.github.com/repos/pandas-dev/pandas...
# 13  1204039393  https://api.github.com/repos/pandas-dev/pandas...
# 14  1203768268  https://api.github.com/repos/pandas-dev/pandas...
# 15  1203632158  https://api.github.com/repos/pandas-dev/pandas...
# 16  1203606102  https://api.github.com/repos/pandas-dev/pandas...
# 17  1203529564  https://api.github.com/repos/pandas-dev/pandas...
# 18  1203443826  https://api.github.com/repos/pandas-dev/pandas...
# 19  1203409750  https://api.github.com/repos/pandas-dev/pandas...
# 20  1203095324  https://api.github.com/repos/pandas-dev/pandas...
# 21  1203080465  https://api.github.com/repos/pandas-dev/pandas...
# 22  1202686797  https://api.github.com/repos/pandas-dev/pandas...
# 23  1202397187  https://api.github.com/repos/pandas-dev/pandas...
# 24  1202186120  https://api.github.com/repos/pandas-dev/pandas...
# 25  1201795845  https://api.github.com/repos/pandas-dev/pandas...
# 26  1201790266  https://api.github.com/repos/pandas-dev/pandas...
# 27  1201718237  https://api.github.com/repos/pandas-dev/pandas...
# 28  1201449320  https://api.github.com/repos/pandas-dev/pandas...
# 29  1200431802  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user
# 0   {'login': 'NickCrews', 'id': 10820686, 'node_i...
# 1   {'login': 'LucasG0', 'id': 44552904, 'node_id'...
# 2   {'login': 'eromoe', 'id': 3938751, 'node_id': ...
# 3   {'login': 'datapythonista', 'id': 10058240, 'n...
# 4   {'login': 'lorentzbao', 'id': 19342156, 'node_...
# 5   {'login': 'ehariri', 'id': 21693509, 'node_id'...
# 6   {'login': 'mosc9575', 'id': 68053396, 'node_id...
# 7   {'login': 'shyamsantoki', 'id': 56479219, 'nod...
# 8   {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 9   {'login': 'vruthik', 'id': 59946643, 'node_id'...
# 10  {'login': 'charlesbluca', 'id': 20627856, 'nod...
# 11  {'login': 'andjhall', 'id': 77794567, 'node_id...
# 12  {'login': 'simonjayhawkins', 'id': 13159005, '...
# 13  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 14  {'login': 'ma3da', 'id': 34522496, 'node_id': ...
# 15  {'login': 'kwhkim', 'id': 4476168, 'node_id': ...
# 16  {'login': 'galipremsagar', 'id': 11664259, 'no...
# 17  {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...
# 18  {'login': 'Moisan', 'id': 31669, 'node_id': 'M...
# 19  {'login': 'maalgorium', 'id': 18078278, 'node_...
# 20  {'login': 'andreareina', 'id': 5351947, 'node_...
# 21  {'login': 'douglas-raillard-arm', 'id': 233368...
# 22  {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...
# 23  {'login': 'smarie', 'id': 3236794, 'node_id': ...
# 24  {'login': 'gwerbin', 'id': 5758789, 'node_id':...
# 25  {'login': 'RogerThomas', 'id': 3211163, 'node_...
# 26  {'login': 'RogerThomas', 'id': 3211163, 'node_...
# 27  {'login': 'cmjcharlton', 'id': 90400333, 'node...
# 28  {'login': 'jakirkham', 'id': 3019665, 'node_id...
# 29  {'login': 'gwerbin', 'id': 5758789, 'node_id':...

# %%
df2.to_csv('json_response.csv')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1E4D-DCE3
#
#  Directory of C:\Users\PRASHANT KUMAR
#
# 19-04-2022  14:47    <DIR>          .
# 16-01-2022  13:18    <DIR>          ..
# 15-12-2019  12:13    <DIR>          .anaconda
# 14-02-2020  11:35    <DIR>          .android
# 17-01-2020  11:04    <DIR>          .AndroidStudio3.5
# 21-07-2020  17:20               145 .appletviewer
# 25-03-2022  10:52             1,010 .bash_history
# 29-06-2021  14:36    <DIR>          .cache
# 25-02-2022  09:33    <DIR>          .conda
# 15-10-2020  13:05                43 .condarc
# 08-02-2020  15:55    <DIR>          .config
# 28-11-2021  13:34    <DIR>          .continuum
# 14-06-2020  13:49    <DIR>          .dotnet
# 11-03-2020  18:33    <DIR>          .eclipse
# 17-01-2020  11:55                16 .emulator_console_auth_token
# 25-03-2022  09:44               214 .gitconfig
# 25-03-2022  09:04            12,288 .gitconfig.swp
# 17-01-2020  11:55    <DIR>          .gradle
# 07-02-2020  16:05    <DIR>          .idlerc
# 19-04-2022  13:12    <DIR>          .ipynb_checkpoints
# 15-12-2019  01:37    <DIR>          .ipython
# 19-12-2021  11:28    <DIR>          .jupyter
# 28-07-2020  20:31    <DIR>          .m2
# 14-12-2019  15:17    <DIR>          .nbi
# 29-06-2021  14:50    <DIR>          .p2
# 02-12-2021  09:25    <DIR>          .spyder-py3
# 11-03-2020  18:33    <DIR>          .tooling
# 25-03-2022  09:05               762 .viminfo
# 25-12-2021  16:01    <DIR>          .VirtualBox
# 14-12-2019  18:39    <DIR>          .vscode
# 13-03-2022  15:36    <DIR>          __pycache__
# 26-12-2021  09:38             3,504 21st dec(for,while).ipynb
# 24-08-2021  15:06    <DIR>          3D Objects
# 23-03-2022  17:10             7,566 Abstraction.ipynb
# 14-02-2020  12:38    <DIR>          AndroidStudioProjects
# 28-01-2022  11:39               149 arithmatic.py
# 04-04-2022  09:01            51,867 car.data
# 07-04-2022  16:34           628,633 carbon_nanotubes.csv
# 15-04-2022  16:33             1,631 Casandra.ipynb
# 21-12-2021  12:45             7,578 conditional statement.ipynb
# 16-01-2022  15:37    <DIR>          Contacts
# 18-04-2022  14:16             1,308 cricket.csv
# 18-04-2022  14:45    <DIR>          Desktop
# 07-03-2022  18:09    <DIR>          Documents
# 19-04-2022  13:10    <DIR>          Downloads
# 29-06-2021  14:05    <DIR>          eclipse
# 29-06-2021  12:21    <DIR>          eclipse-workspace
# 02-02-2022  20:52            33,366 Exception Handling.ipynb
# 16-01-2022  15:37    <DIR>          Favorites
# 24-12-2021  14:54            13,457 for, while,lambda.ipynb
# 11-01-2022  16:25            34,720 function with argument,iterable,iterator.ipynb
# 29-12-2021  12:40            14,911 Function(23th Dec).ipynb
# 18-01-2022  16:02            67,764 generator,file operation.ipynb
# 01-04-2022  11:24            11,903 glass.data
# 16-10-2021  14:43    <DIR>          IBA_IOAPDATA
# 19-04-2022  13:15             5,658 icc.csv
# 14-04-2022  08:13             8,192 ineuron.db
# 21-03-2022  15:51            51,131 Inheritance.ipynb
# 14-04-2022  13:35            12,288 joindb.db
# 19-04-2022  14:47            34,698 json_response.csv
# 16-01-2022  15:37    <DIR>          Links
# 16-04-2022  14:30           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 16-04-2022  14:30           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 16-04-2022  14:30            95,503 LUSID Excel - Manage instruments with economic definitions.xlsx
# 16-04-2022  14:30            84,319 LUSID Excel - Manage Orders.xlsx
# 16-04-2022  14:30           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 16-04-2022  14:30           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 16-04-2022  14:30           136,632 LUSID Excel - Setting up your market data.xlsx
# 28-01-2022  12:37             8,176 modules and package.ipynb
# 07-04-2022  16:41            37,174 Mongodb.ipynb
# 16-01-2022  15:37    <DIR>          Music
# 13-03-2022  15:35               635 mydict.py
# 18-04-2022  13:38            78,961 NBA.csv
# 27-01-2022  11:26    <DIR>          OneDrive
# 13-03-2022  16:07             1,641 Oops(Part1).ipynb
# 13-03-2022  20:42            17,056 oops.ipynb
# 14-12-2019  15:55    <DIR>          Oracle
# 19-04-2022  13:12           576,990 pandas day 2.ipynb
# 19-04-2022  14:45           644,715 Pandas(2).ipynb
# 18-04-2022  12:32           206,347 Pandas.ipynb
# 14-04-2022  08:11             8,192 person.db
# 16-01-2022  15:37    <DIR>          Pictures
# 23-03-2022  17:10             9,704 polymorphism.ipynb
# 09-03-2022  09:11    <DIR>          PycharmProjects
# 25-03-2022  09:14    <DIR>          Python
# 19-01-2022  16:27            37,898 Questions.ipynb
# 16-04-2022  13:53               244 sample_test.csv
# 16-01-2022  15:37    <DIR>          Saved Games
# 16-01-2022  15:37    <DIR>          Searches
# 14-12-2019  18:13    <DIR>          source
# 01-04-2022  13:05           124,230 sql connection(part-1).ipynb
# 04-04-2022  13:47           492,986 sql(part-2).ipynb
# 14-04-2022  16:22            64,198 SqlLite,map,reduce,filter,zip.ipynb
# 16-11-2020  19:41       114,273,560 Teams_windows_x64.exe
# 25-01-2022  21:15               179 test.log
# 18-01-2022  14:34                 0 test.txt
# 16-03-2022  21:25                22 test1.txt
# 25-01-2022  21:34               719 test2.log
# 18-01-2022  14:40                21 test2.txt
# 28-01-2022  11:31               154 test22.py
# 25-01-2022  21:38                 0 test3.log
# 18-01-2022  14:30                 0 text.txt
# 28-11-2021  09:11    <DIR>          Tracing
# 30-03-2022  15:47             1,858 Untitled.ipynb
# 04-12-2021  14:23            14,021 Untitled1.ipynb
# 11-01-2022  16:09            34,720 Untitled15.ipynb
# 12-01-2022  14:08             4,789 Untitled16.ipynb
# 05-12-2021  13:48            15,628 Untitled2.ipynb
# 18-12-2021  15:27            17,346 Untitled3.ipynb
# 22-01-2022  13:11            12,826 Untitled4.ipynb
# 19-12-2021  12:54             7,580 Untitled5.ipynb
# 21-12-2021  12:33             3,794 Untitled6.ipynb
# 23-03-2022  10:42                72 Untitled7.ipynb
# 23-03-2022  14:29                72 Untitled8.ipynb
# 16-01-2022  15:37    <DIR>          Videos
# 16-11-2020  19:16       102,233,600 webexapp.msi
# 27-12-2021  10:39            10,289 while.ipynb
#               71 File(s)    220,906,480 bytes
#               46 Dir(s)  119,000,162,304 bytes free

# %%
df2['user']
# Out:
# 0     {'login': 'NickCrews', 'id': 10820686, 'node_i...
# 1     {'login': 'LucasG0', 'id': 44552904, 'node_id'...
# 2     {'login': 'eromoe', 'id': 3938751, 'node_id': ...
# 3     {'login': 'datapythonista', 'id': 10058240, 'n...
# 4     {'login': 'lorentzbao', 'id': 19342156, 'node_...
# 5     {'login': 'ehariri', 'id': 21693509, 'node_id'...
# 6     {'login': 'mosc9575', 'id': 68053396, 'node_id...
# 7     {'login': 'shyamsantoki', 'id': 56479219, 'nod...
# 8     {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 9     {'login': 'vruthik', 'id': 59946643, 'node_id'...
# 10    {'login': 'charlesbluca', 'id': 20627856, 'nod...
# 11    {'login': 'andjhall', 'id': 77794567, 'node_id...
# 12    {'login': 'simonjayhawkins', 'id': 13159005, '...
# 13    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 14    {'login': 'ma3da', 'id': 34522496, 'node_id': ...
# 15    {'login': 'kwhkim', 'id': 4476168, 'node_id': ...
# 16    {'login': 'galipremsagar', 'id': 11664259, 'no...
# 17    {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...
# 18    {'login': 'Moisan', 'id': 31669, 'node_id': 'M...
# 19    {'login': 'maalgorium', 'id': 18078278, 'node_...
# 20    {'login': 'andreareina', 'id': 5351947, 'node_...
# 21    {'login': 'douglas-raillard-arm', 'id': 233368...
# 22    {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...
# 23    {'login': 'smarie', 'id': 3236794, 'node_id': ...
# 24    {'login': 'gwerbin', 'id': 5758789, 'node_id':...
# 25    {'login': 'RogerThomas', 'id': 3211163, 'node_...
# 26    {'login': 'RogerThomas', 'id': 3211163, 'node_...
# 27    {'login': 'cmjcharlton', 'id': 90400333, 'node...
# 28    {'login': 'jakirkham', 'id': 3019665, 'node_id...
# 29    {'login': 'gwerbin', 'id': 5758789, 'node_id':...
# Name: user, dtype: object

# %%
new=[]
for i in df2['user']:
    new.append(i)
df3=pd.DataFrame(new)

# %%
df3
# Out:
#                    login        id               node_id  \
# 0              NickCrews  10820686  MDQ6VXNlcjEwODIwNjg2
# 1                LucasG0  44552904  MDQ6VXNlcjQ0NTUyOTA0
# 2                 eromoe   3938751  MDQ6VXNlcjM5Mzg3NTE=
# 3         datapythonista  10058240  MDQ6VXNlcjEwMDU4MjQw
# 4             lorentzbao  19342156  MDQ6VXNlcjE5MzQyMTU2
# 5                ehariri  21693509  MDQ6VXNlcjIxNjkzNTA5
# 6               mosc9575  68053396  MDQ6VXNlcjY4MDUzMzk2
# 7           shyamsantoki  56479219  MDQ6VXNlcjU2NDc5MjE5
# 8             twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# 9                vruthik  59946643  MDQ6VXNlcjU5OTQ2NjQz
# 10          charlesbluca  20627856  MDQ6VXNlcjIwNjI3ODU2
# 11              andjhall  77794567  MDQ6VXNlcjc3Nzk0NTY3
# 12       simonjayhawkins  13159005  MDQ6VXNlcjEzMTU5MDA1
# 13             mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 14                 ma3da  34522496  MDQ6VXNlcjM0NTIyNDk2
# 15                kwhkim   4476168  MDQ6VXNlcjQ0NzYxNjg=
# 16         galipremsagar  11664259  MDQ6VXNlcjExNjY0MjU5
# 17                Dr-Irv  15113894  MDQ6VXNlcjE1MTEzODk0
# 18                Moisan     31669      MDQ6VXNlcjMxNjY5
# 19            maalgorium  18078278  MDQ6VXNlcjE4MDc4Mjc4
# 20           andreareina   5351947  MDQ6VXNlcjUzNTE5NDc=
# 21  douglas-raillard-arm  23336875  MDQ6VXNlcjIzMzM2ODc1
# 22                Dr-Irv  15113894  MDQ6VXNlcjE1MTEzODk0
# 23                smarie   3236794  MDQ6VXNlcjMyMzY3OTQ=
# 24               gwerbin   5758789  MDQ6VXNlcjU3NTg3ODk=
# 25           RogerThomas   3211163  MDQ6VXNlcjMyMTExNjM=
# 26           RogerThomas   3211163  MDQ6VXNlcjMyMTExNjM=
# 27           cmjcharlton  90400333  MDQ6VXNlcjkwNDAwMzMz
# 28             jakirkham   3019665  MDQ6VXNlcjMwMTk2NjU=
# 29               gwerbin   5758789  MDQ6VXNlcjU3NTg3ODk=
#
#                                            avatar_url gravatar_id  \
# 0   https://avatars.githubusercontent.com/u/108206...
# 1   https://avatars.githubusercontent.com/u/445529...
# 2   https://avatars.githubusercontent.com/u/393875...
# 3   https://avatars.githubusercontent.com/u/100582...
# 4   https://avatars.githubusercontent.com/u/193421...
# 5   https://avatars.githubusercontent.com/u/216935...
# 6   https://avatars.githubusercontent.com/u/680533...
# 7   https://avatars.githubusercontent.com/u/564792...
# 8   https://avatars.githubusercontent.com/u/661816...
# 9   https://avatars.githubusercontent.com/u/599466...
# 10  https://avatars.githubusercontent.com/u/206278...
# 11  https://avatars.githubusercontent.com/u/777945...
# 12  https://avatars.githubusercontent.com/u/131590...
# 13  https://avatars.githubusercontent.com/u/106470...
# 14  https://avatars.githubusercontent.com/u/345224...
# 15  https://avatars.githubusercontent.com/u/447616...
# 16  https://avatars.githubusercontent.com/u/116642...
# 17  https://avatars.githubusercontent.com/u/151138...
# 18  https://avatars.githubusercontent.com/u/31669?v=4
# 19  https://avatars.githubusercontent.com/u/180782...
# 20  https://avatars.githubusercontent.com/u/535194...
# 21  https://avatars.githubusercontent.com/u/233368...
# 22  https://avatars.githubusercontent.com/u/151138...
# 23  https://avatars.githubusercontent.com/u/323679...
# 24  https://avatars.githubusercontent.com/u/575878...
# 25  https://avatars.githubusercontent.com/u/321116...
# 26  https://avatars.githubusercontent.com/u/321116...
# 27  https://avatars.githubusercontent.com/u/904003...
# 28  https://avatars.githubusercontent.com/u/301966...
# 29  https://avatars.githubusercontent.com/u/575878...
#
#                                                   url  \
# 0              https://api.github.com/users/NickCrews
# 1                https://api.github.com/users/LucasG0
# 2                 https://api.github.com/users/eromoe
# 3         https://api.github.com/users/datapythonista
# 4             https://api.github.com/users/lorentzbao
# 5                https://api.github.com/users/ehariri
# 6               https://api.github.com/users/mosc9575
# 7           https://api.github.com/users/shyamsantoki
# 8             https://api.github.com/users/twoertwein
# 9                https://api.github.com/users/vruthik
# 10          https://api.github.com/users/charlesbluca
# 11              https://api.github.com/users/andjhall
# 12       https://api.github.com/users/simonjayhawkins
# 13             https://api.github.com/users/mroeschke
# 14                 https://api.github.com/users/ma3da
# 15                https://api.github.com/users/kwhkim
# 16         https://api.github.com/users/galipremsagar
# 17                https://api.github.com/users/Dr-Irv
# 18                https://api.github.com/users/Moisan
# 19            https://api.github.com/users/maalgorium
# 20           https://api.github.com/users/andreareina
# 21  https://api.github.com/users/douglas-raillard-arm
# 22                https://api.github.com/users/Dr-Irv
# 23                https://api.github.com/users/smarie
# 24               https://api.github.com/users/gwerbin
# 25           https://api.github.com/users/RogerThomas
# 26           https://api.github.com/users/RogerThomas
# 27           https://api.github.com/users/cmjcharlton
# 28             https://api.github.com/users/jakirkham
# 29               https://api.github.com/users/gwerbin
#
#                                    html_url  \
# 0              https://github.com/NickCrews
# 1                https://github.com/LucasG0
# 2                 https://github.com/eromoe
# 3         https://github.com/datapythonista
# 4             https://github.com/lorentzbao
# 5                https://github.com/ehariri
# 6               https://github.com/mosc9575
# 7           https://github.com/shyamsantoki
# 8             https://github.com/twoertwein
# 9                https://github.com/vruthik
# 10          https://github.com/charlesbluca
# 11              https://github.com/andjhall
# 12       https://github.com/simonjayhawkins
# 13             https://github.com/mroeschke
# 14                 https://github.com/ma3da
# 15                https://github.com/kwhkim
# 16         https://github.com/galipremsagar
# 17                https://github.com/Dr-Irv
# 18                https://github.com/Moisan
# 19            https://github.com/maalgorium
# 20           https://github.com/andreareina
# 21  https://github.com/douglas-raillard-arm
# 22                https://github.com/Dr-Irv
# 23                https://github.com/smarie
# 24               https://github.com/gwerbin
# 25           https://github.com/RogerThomas
# 26           https://github.com/RogerThomas
# 27           https://github.com/cmjcharlton
# 28             https://github.com/jakirkham
# 29               https://github.com/gwerbin
#
#                                         followers_url  \
# 0    https://api.github.com/users/NickCrews/followers
# 1      https://api.github.com/users/LucasG0/followers
# 2       https://api.github.com/users/eromoe/followers
# 3   https://api.github.com/users/datapythonista/fo...
# 4   https://api.github.com/users/lorentzbao/followers
# 5      https://api.github.com/users/ehariri/followers
# 6     https://api.github.com/users/mosc9575/followers
# 7   https://api.github.com/users/shyamsantoki/foll...
# 8   https://api.github.com/users/twoertwein/followers
# 9      https://api.github.com/users/vruthik/followers
# 10  https://api.github.com/users/charlesbluca/foll...
# 11    https://api.github.com/users/andjhall/followers
# 12  https://api.github.com/users/simonjayhawkins/f...
# 13   https://api.github.com/users/mroeschke/followers
# 14       https://api.github.com/users/ma3da/followers
# 15      https://api.github.com/users/kwhkim/followers
# 16  https://api.github.com/users/galipremsagar/fol...
# 17      https://api.github.com/users/Dr-Irv/followers
# 18      https://api.github.com/users/Moisan/followers
# 19  https://api.github.com/users/maalgorium/followers
# 20  https://api.github.com/users/andreareina/follo...
# 21  https://api.github.com/users/douglas-raillard-...
# 22      https://api.github.com/users/Dr-Irv/followers
# 23      https://api.github.com/users/smarie/followers
# 24     https://api.github.com/users/gwerbin/followers
# 25  https://api.github.com/users/RogerThomas/follo...
# 26  https://api.github.com/users/RogerThomas/follo...
# 27  https://api.github.com/users/cmjcharlton/follo...
# 28   https://api.github.com/users/jakirkham/followers
# 29     https://api.github.com/users/gwerbin/followers
#
#                                         following_url  \
# 0   https://api.github.com/users/NickCrews/followi...
# 1   https://api.github.com/users/LucasG0/following...
# 2   https://api.github.com/users/eromoe/following{...
# 3   https://api.github.com/users/datapythonista/fo...
# 4   https://api.github.com/users/lorentzbao/follow...
# 5   https://api.github.com/users/ehariri/following...
# 6   https://api.github.com/users/mosc9575/followin...
# 7   https://api.github.com/users/shyamsantoki/foll...
# 8   https://api.github.com/users/twoertwein/follow...
# 9   https://api.github.com/users/vruthik/following...
# 10  https://api.github.com/users/charlesbluca/foll...
# 11  https://api.github.com/users/andjhall/followin...
# 12  https://api.github.com/users/simonjayhawkins/f...
# 13  https://api.github.com/users/mroeschke/followi...
# 14  https://api.github.com/users/ma3da/following{/...
# 15  https://api.github.com/users/kwhkim/following{...
# 16  https://api.github.com/users/galipremsagar/fol...
# 17  https://api.github.com/users/Dr-Irv/following{...
# 18  https://api.github.com/users/Moisan/following{...
# 19  https://api.github.com/users/maalgorium/follow...
# 20  https://api.github.com/users/andreareina/follo...
# 21  https://api.github.com/users/douglas-raillard-...
# 22  https://api.github.com/users/Dr-Irv/following{...
# 23  https://api.github.com/users/smarie/following{...
# 24  https://api.github.com/users/gwerbin/following...
# 25  https://api.github.com/users/RogerThomas/follo...
# 26  https://api.github.com/users/RogerThomas/follo...
# 27  https://api.github.com/users/cmjcharlton/follo...
# 28  https://api.github.com/users/jakirkham/followi...
# 29  https://api.github.com/users/gwerbin/following...
#
#                                             gists_url  \
# 0   https://api.github.com/users/NickCrews/gists{/...
# 1   https://api.github.com/users/LucasG0/gists{/gi...
# 2   https://api.github.com/users/eromoe/gists{/gis...
# 3   https://api.github.com/users/datapythonista/gi...
# 4   https://api.github.com/users/lorentzbao/gists{...
# 5   https://api.github.com/users/ehariri/gists{/gi...
# 6   https://api.github.com/users/mosc9575/gists{/g...
# 7   https://api.github.com/users/shyamsantoki/gist...
# 8   https://api.github.com/users/twoertwein/gists{...
# 9   https://api.github.com/users/vruthik/gists{/gi...
# 10  https://api.github.com/users/charlesbluca/gist...
# 11  https://api.github.com/users/andjhall/gists{/g...
# 12  https://api.github.com/users/simonjayhawkins/g...
# 13  https://api.github.com/users/mroeschke/gists{/...
# 14  https://api.github.com/users/ma3da/gists{/gist...
# 15  https://api.github.com/users/kwhkim/gists{/gis...
# 16  https://api.github.com/users/galipremsagar/gis...
# 17  https://api.github.com/users/Dr-Irv/gists{/gis...
# 18  https://api.github.com/users/Moisan/gists{/gis...
# 19  https://api.github.com/users/maalgorium/gists{...
# 20  https://api.github.com/users/andreareina/gists...
# 21  https://api.github.com/users/douglas-raillard-...
# 22  https://api.github.com/users/Dr-Irv/gists{/gis...
# 23  https://api.github.com/users/smarie/gists{/gis...
# 24  https://api.github.com/users/gwerbin/gists{/gi...
# 25  https://api.github.com/users/RogerThomas/gists...
# 26  https://api.github.com/users/RogerThomas/gists...
# 27  https://api.github.com/users/cmjcharlton/gists...
# 28  https://api.github.com/users/jakirkham/gists{/...
# 29  https://api.github.com/users/gwerbin/gists{/gi...
#
#                                           starred_url  \
# 0   https://api.github.com/users/NickCrews/starred...
# 1   https://api.github.com/users/LucasG0/starred{/...
# 2   https://api.github.com/users/eromoe/starred{/o...
# 3   https://api.github.com/users/datapythonista/st...
# 4   https://api.github.com/users/lorentzbao/starre...
# 5   https://api.github.com/users/ehariri/starred{/...
# 6   https://api.github.com/users/mosc9575/starred{...
# 7   https://api.github.com/users/shyamsantoki/star...
# 8   https://api.github.com/users/twoertwein/starre...
# 9   https://api.github.com/users/vruthik/starred{/...
# 10  https://api.github.com/users/charlesbluca/star...
# 11  https://api.github.com/users/andjhall/starred{...
# 12  https://api.github.com/users/simonjayhawkins/s...
# 13  https://api.github.com/users/mroeschke/starred...
# 14  https://api.github.com/users/ma3da/starred{/ow...
# 15  https://api.github.com/users/kwhkim/starred{/o...
# 16  https://api.github.com/users/galipremsagar/sta...
# 17  https://api.github.com/users/Dr-Irv/starred{/o...
# 18  https://api.github.com/users/Moisan/starred{/o...
# 19  https://api.github.com/users/maalgorium/starre...
# 20  https://api.github.com/users/andreareina/starr...
# 21  https://api.github.com/users/douglas-raillard-...
# 22  https://api.github.com/users/Dr-Irv/starred{/o...
# 23  https://api.github.com/users/smarie/starred{/o...
# 24  https://api.github.com/users/gwerbin/starred{/...
# 25  https://api.github.com/users/RogerThomas/starr...
# 26  https://api.github.com/users/RogerThomas/starr...
# 27  https://api.github.com/users/cmjcharlton/starr...
# 28  https://api.github.com/users/jakirkham/starred...
# 29  https://api.github.com/users/gwerbin/starred{/...
#
#                                     subscriptions_url  \
# 0   https://api.github.com/users/NickCrews/subscri...
# 1   https://api.github.com/users/LucasG0/subscript...
# 2   https://api.github.com/users/eromoe/subscriptions
# 3   https://api.github.com/users/datapythonista/su...
# 4   https://api.github.com/users/lorentzbao/subscr...
# 5   https://api.github.com/users/ehariri/subscript...
# 6   https://api.github.com/users/mosc9575/subscrip...
# 7   https://api.github.com/users/shyamsantoki/subs...
# 8   https://api.github.com/users/twoertwein/subscr...
# 9   https://api.github.com/users/vruthik/subscript...
# 10  https://api.github.com/users/charlesbluca/subs...
# 11  https://api.github.com/users/andjhall/subscrip...
# 12  https://api.github.com/users/simonjayhawkins/s...
# 13  https://api.github.com/users/mroeschke/subscri...
# 14   https://api.github.com/users/ma3da/subscriptions
# 15  https://api.github.com/users/kwhkim/subscriptions
# 16  https://api.github.com/users/galipremsagar/sub...
# 17  https://api.github.com/users/Dr-Irv/subscriptions
# 18  https://api.github.com/users/Moisan/subscriptions
# 19  https://api.github.com/users/maalgorium/subscr...
# 20  https://api.github.com/users/andreareina/subsc...
# 21  https://api.github.com/users/douglas-raillard-...
# 22  https://api.github.com/users/Dr-Irv/subscriptions
# 23  https://api.github.com/users/smarie/subscriptions
# 24  https://api.github.com/users/gwerbin/subscript...
# 25  https://api.github.com/users/RogerThomas/subsc...
# 26  https://api.github.com/users/RogerThomas/subsc...
# 27  https://api.github.com/users/cmjcharlton/subsc...
# 28  https://api.github.com/users/jakirkham/subscri...
# 29  https://api.github.com/users/gwerbin/subscript...
#
#                                     organizations_url  \
# 0         https://api.github.com/users/NickCrews/orgs
# 1           https://api.github.com/users/LucasG0/orgs
# 2            https://api.github.com/users/eromoe/orgs
# 3    https://api.github.com/users/datapythonista/orgs
# 4        https://api.github.com/users/lorentzbao/orgs
# 5           https://api.github.com/users/ehariri/orgs
# 6          https://api.github.com/users/mosc9575/orgs
# 7      https://api.github.com/users/shyamsantoki/orgs
# 8        https://api.github.com/users/twoertwein/orgs
# 9           https://api.github.com/users/vruthik/orgs
# 10     https://api.github.com/users/charlesbluca/orgs
# 11         https://api.github.com/users/andjhall/orgs
# 12  https://api.github.com/users/simonjayhawkins/orgs
# 13        https://api.github.com/users/mroeschke/orgs
# 14            https://api.github.com/users/ma3da/orgs
# 15           https://api.github.com/users/kwhkim/orgs
# 16    https://api.github.com/users/galipremsagar/orgs
# 17           https://api.github.com/users/Dr-Irv/orgs
# 18           https://api.github.com/users/Moisan/orgs
# 19       https://api.github.com/users/maalgorium/orgs
# 20      https://api.github.com/users/andreareina/orgs
# 21  https://api.github.com/users/douglas-raillard-...
# 22           https://api.github.com/users/Dr-Irv/orgs
# 23           https://api.github.com/users/smarie/orgs
# 24          https://api.github.com/users/gwerbin/orgs
# 25      https://api.github.com/users/RogerThomas/orgs
# 26      https://api.github.com/users/RogerThomas/orgs
# 27      https://api.github.com/users/cmjcharlton/orgs
# 28        https://api.github.com/users/jakirkham/orgs
# 29          https://api.github.com/users/gwerbin/orgs
#
#                                             repos_url  \
# 0        https://api.github.com/users/NickCrews/repos
# 1          https://api.github.com/users/LucasG0/repos
# 2           https://api.github.com/users/eromoe/repos
# 3   https://api.github.com/users/datapythonista/repos
# 4       https://api.github.com/users/lorentzbao/repos
# 5          https://api.github.com/users/ehariri/repos
# 6         https://api.github.com/users/mosc9575/repos
# 7     https://api.github.com/users/shyamsantoki/repos
# 8       https://api.github.com/users/twoertwein/repos
# 9          https://api.github.com/users/vruthik/repos
# 10    https://api.github.com/users/charlesbluca/repos
# 11        https://api.github.com/users/andjhall/repos
# 12  https://api.github.com/users/simonjayhawkins/r...
# 13       https://api.github.com/users/mroeschke/repos
# 14           https://api.github.com/users/ma3da/repos
# 15          https://api.github.com/users/kwhkim/repos
# 16   https://api.github.com/users/galipremsagar/repos
# 17          https://api.github.com/users/Dr-Irv/repos
# 18          https://api.github.com/users/Moisan/repos
# 19      https://api.github.com/users/maalgorium/repos
# 20     https://api.github.com/users/andreareina/repos
# 21  https://api.github.com/users/douglas-raillard-...
# 22          https://api.github.com/users/Dr-Irv/repos
# 23          https://api.github.com/users/smarie/repos
# 24         https://api.github.com/users/gwerbin/repos
# 25     https://api.github.com/users/RogerThomas/repos
# 26     https://api.github.com/users/RogerThomas/repos
# 27     https://api.github.com/users/cmjcharlton/repos
# 28       https://api.github.com/users/jakirkham/repos
# 29         https://api.github.com/users/gwerbin/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/NickCrews/events{...
# 1   https://api.github.com/users/LucasG0/events{/p...
# 2   https://api.github.com/users/eromoe/events{/pr...
# 3   https://api.github.com/users/datapythonista/ev...
# 4   https://api.github.com/users/lorentzbao/events...
# 5   https://api.github.com/users/ehariri/events{/p...
# 6   https://api.github.com/users/mosc9575/events{/...
# 7   https://api.github.com/users/shyamsantoki/even...
# 8   https://api.github.com/users/twoertwein/events...
# 9   https://api.github.com/users/vruthik/events{/p...
# 10  https://api.github.com/users/charlesbluca/even...
# 11  https://api.github.com/users/andjhall/events{/...
# 12  https://api.github.com/users/simonjayhawkins/e...
# 13  https://api.github.com/users/mroeschke/events{...
# 14  https://api.github.com/users/ma3da/events{/pri...
# 15  https://api.github.com/users/kwhkim/events{/pr...
# 16  https://api.github.com/users/galipremsagar/eve...
# 17  https://api.github.com/users/Dr-Irv/events{/pr...
# 18  https://api.github.com/users/Moisan/events{/pr...
# 19  https://api.github.com/users/maalgorium/events...
# 20  https://api.github.com/users/andreareina/event...
# 21  https://api.github.com/users/douglas-raillard-...
# 22  https://api.github.com/users/Dr-Irv/events{/pr...
# 23  https://api.github.com/users/smarie/events{/pr...
# 24  https://api.github.com/users/gwerbin/events{/p...
# 25  https://api.github.com/users/RogerThomas/event...
# 26  https://api.github.com/users/RogerThomas/event...
# 27  https://api.github.com/users/cmjcharlton/event...
# 28  https://api.github.com/users/jakirkham/events{...
# 29  https://api.github.com/users/gwerbin/events{/p...
#
#                                   received_events_url  type  site_admin
# 0   https://api.github.com/users/NickCrews/receive...  User       False
# 1   https://api.github.com/users/LucasG0/received_...  User       False
# 2   https://api.github.com/users/eromoe/received_e...  User       False
# 3   https://api.github.com/users/datapythonista/re...  User       False
# 4   https://api.github.com/users/lorentzbao/receiv...  User       False
# 5   https://api.github.com/users/ehariri/received_...  User       False
# 6   https://api.github.com/users/mosc9575/received...  User       False
# 7   https://api.github.com/users/shyamsantoki/rece...  User       False
# 8   https://api.github.com/users/twoertwein/receiv...  User       False
# 9   https://api.github.com/users/vruthik/received_...  User       False
# 10  https://api.github.com/users/charlesbluca/rece...  User       False
# 11  https://api.github.com/users/andjhall/received...  User       False
# 12  https://api.github.com/users/simonjayhawkins/r...  User       False
# 13  https://api.github.com/users/mroeschke/receive...  User       False
# 14  https://api.github.com/users/ma3da/received_ev...  User       False
# 15  https://api.github.com/users/kwhkim/received_e...  User       False
# 16  https://api.github.com/users/galipremsagar/rec...  User       False
# 17  https://api.github.com/users/Dr-Irv/received_e...  User       False
# 18  https://api.github.com/users/Moisan/received_e...  User       False
# 19  https://api.github.com/users/maalgorium/receiv...  User       False
# 20  https://api.github.com/users/andreareina/recei...  User       False
# 21  https://api.github.com/users/douglas-raillard-...  User       False
# 22  https://api.github.com/users/Dr-Irv/received_e...  User       False
# 23  https://api.github.com/users/smarie/received_e...  User       False
# 24  https://api.github.com/users/gwerbin/received_...  User       False
# 25  https://api.github.com/users/RogerThomas/recei...  User       False
# 26  https://api.github.com/users/RogerThomas/recei...  User       False
# 27  https://api.github.com/users/cmjcharlton/recei...  User       False
# 28  https://api.github.com/users/jakirkham/receive...  User       False
# 29  https://api.github.com/users/gwerbin/received_...  User       False

# %%
len(df3)
# Out:
# 30

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
result=pd.concat([df2,df3],axis=1,join='inner')

# %%
result
# Out:
#             id                                                url  \
# 0   1207499980  https://api.github.com/repos/pandas-dev/pandas...
# 1   1207172802  https://api.github.com/repos/pandas-dev/pandas...
# 2   1206612518  https://api.github.com/repos/pandas-dev/pandas...
# 3   1206370745  https://api.github.com/repos/pandas-dev/pandas...
# 4   1206301209  https://api.github.com/repos/pandas-dev/pandas...
# 5   1206170540  https://api.github.com/repos/pandas-dev/pandas...
# 6   1206164359  https://api.github.com/repos/pandas-dev/pandas...
# 7   1206141718  https://api.github.com/repos/pandas-dev/pandas...
# 8   1205872267  https://api.github.com/repos/pandas-dev/pandas...
# 9   1205765682  https://api.github.com/repos/pandas-dev/pandas...
# 10  1205740295  https://api.github.com/repos/pandas-dev/pandas...
# 11  1204912401  https://api.github.com/repos/pandas-dev/pandas...
# 12  1204378879  https://api.github.com/repos/pandas-dev/pandas...
# 13  1204039393  https://api.github.com/repos/pandas-dev/pandas...
# 14  1203768268  https://api.github.com/repos/pandas-dev/pandas...
# 15  1203632158  https://api.github.com/repos/pandas-dev/pandas...
# 16  1203606102  https://api.github.com/repos/pandas-dev/pandas...
# 17  1203529564  https://api.github.com/repos/pandas-dev/pandas...
# 18  1203443826  https://api.github.com/repos/pandas-dev/pandas...
# 19  1203409750  https://api.github.com/repos/pandas-dev/pandas...
# 20  1203095324  https://api.github.com/repos/pandas-dev/pandas...
# 21  1203080465  https://api.github.com/repos/pandas-dev/pandas...
# 22  1202686797  https://api.github.com/repos/pandas-dev/pandas...
# 23  1202397187  https://api.github.com/repos/pandas-dev/pandas...
# 24  1202186120  https://api.github.com/repos/pandas-dev/pandas...
# 25  1201795845  https://api.github.com/repos/pandas-dev/pandas...
# 26  1201790266  https://api.github.com/repos/pandas-dev/pandas...
# 27  1201718237  https://api.github.com/repos/pandas-dev/pandas...
# 28  1201449320  https://api.github.com/repos/pandas-dev/pandas...
# 29  1200431802  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user                 login  \
# 0   {'login': 'NickCrews', 'id': 10820686, 'node_i...             NickCrews
# 1   {'login': 'LucasG0', 'id': 44552904, 'node_id'...               LucasG0
# 2   {'login': 'eromoe', 'id': 3938751, 'node_id': ...                eromoe
# 3   {'login': 'datapythonista', 'id': 10058240, 'n...        datapythonista
# 4   {'login': 'lorentzbao', 'id': 19342156, 'node_...            lorentzbao
# 5   {'login': 'ehariri', 'id': 21693509, 'node_id'...               ehariri
# 6   {'login': 'mosc9575', 'id': 68053396, 'node_id...              mosc9575
# 7   {'login': 'shyamsantoki', 'id': 56479219, 'nod...          shyamsantoki
# 8   {'login': 'twoertwein', 'id': 6618166, 'node_i...            twoertwein
# 9   {'login': 'vruthik', 'id': 59946643, 'node_id'...               vruthik
# 10  {'login': 'charlesbluca', 'id': 20627856, 'nod...          charlesbluca
# 11  {'login': 'andjhall', 'id': 77794567, 'node_id...              andjhall
# 12  {'login': 'simonjayhawkins', 'id': 13159005, '...       simonjayhawkins
# 13  {'login': 'mroeschke', 'id': 10647082, 'node_i...             mroeschke
# 14  {'login': 'ma3da', 'id': 34522496, 'node_id': ...                 ma3da
# 15  {'login': 'kwhkim', 'id': 4476168, 'node_id': ...                kwhkim
# 16  {'login': 'galipremsagar', 'id': 11664259, 'no...         galipremsagar
# 17  {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...                Dr-Irv
# 18  {'login': 'Moisan', 'id': 31669, 'node_id': 'M...                Moisan
# 19  {'login': 'maalgorium', 'id': 18078278, 'node_...            maalgorium
# 20  {'login': 'andreareina', 'id': 5351947, 'node_...           andreareina
# 21  {'login': 'douglas-raillard-arm', 'id': 233368...  douglas-raillard-arm
# 22  {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...                Dr-Irv
# 23  {'login': 'smarie', 'id': 3236794, 'node_id': ...                smarie
# 24  {'login': 'gwerbin', 'id': 5758789, 'node_id':...               gwerbin
# 25  {'login': 'RogerThomas', 'id': 3211163, 'node_...           RogerThomas
# 26  {'login': 'RogerThomas', 'id': 3211163, 'node_...           RogerThomas
# 27  {'login': 'cmjcharlton', 'id': 90400333, 'node...           cmjcharlton
# 28  {'login': 'jakirkham', 'id': 3019665, 'node_id...             jakirkham
# 29  {'login': 'gwerbin', 'id': 5758789, 'node_id':...               gwerbin
#
#           id               node_id  \
# 0   10820686  MDQ6VXNlcjEwODIwNjg2
# 1   44552904  MDQ6VXNlcjQ0NTUyOTA0
# 2    3938751  MDQ6VXNlcjM5Mzg3NTE=
# 3   10058240  MDQ6VXNlcjEwMDU4MjQw
# 4   19342156  MDQ6VXNlcjE5MzQyMTU2
# 5   21693509  MDQ6VXNlcjIxNjkzNTA5
# 6   68053396  MDQ6VXNlcjY4MDUzMzk2
# 7   56479219  MDQ6VXNlcjU2NDc5MjE5
# 8    6618166  MDQ6VXNlcjY2MTgxNjY=
# 9   59946643  MDQ6VXNlcjU5OTQ2NjQz
# 10  20627856  MDQ6VXNlcjIwNjI3ODU2
# 11  77794567  MDQ6VXNlcjc3Nzk0NTY3
# 12  13159005  MDQ6VXNlcjEzMTU5MDA1
# 13  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 14  34522496  MDQ6VXNlcjM0NTIyNDk2
# 15   4476168  MDQ6VXNlcjQ0NzYxNjg=
# 16  11664259  MDQ6VXNlcjExNjY0MjU5
# 17  15113894  MDQ6VXNlcjE1MTEzODk0
# 18     31669      MDQ6VXNlcjMxNjY5
# 19  18078278  MDQ6VXNlcjE4MDc4Mjc4
# 20   5351947  MDQ6VXNlcjUzNTE5NDc=
# 21  23336875  MDQ6VXNlcjIzMzM2ODc1
# 22  15113894  MDQ6VXNlcjE1MTEzODk0
# 23   3236794  MDQ6VXNlcjMyMzY3OTQ=
# 24   5758789  MDQ6VXNlcjU3NTg3ODk=
# 25   3211163  MDQ6VXNlcjMyMTExNjM=
# 26   3211163  MDQ6VXNlcjMyMTExNjM=
# 27  90400333  MDQ6VXNlcjkwNDAwMzMz
# 28   3019665  MDQ6VXNlcjMwMTk2NjU=
# 29   5758789  MDQ6VXNlcjU3NTg3ODk=
#
#                                            avatar_url gravatar_id  ...  \
# 0   https://avatars.githubusercontent.com/u/108206...              ...
# 1   https://avatars.githubusercontent.com/u/445529...              ...
# 2   https://avatars.githubusercontent.com/u/393875...              ...
# 3   https://avatars.githubusercontent.com/u/100582...              ...
# 4   https://avatars.githubusercontent.com/u/193421...              ...
# 5   https://avatars.githubusercontent.com/u/216935...              ...
# 6   https://avatars.githubusercontent.com/u/680533...              ...
# 7   https://avatars.githubusercontent.com/u/564792...              ...
# 8   https://avatars.githubusercontent.com/u/661816...              ...
# 9   https://avatars.githubusercontent.com/u/599466...              ...
# 10  https://avatars.githubusercontent.com/u/206278...              ...
# 11  https://avatars.githubusercontent.com/u/777945...              ...
# 12  https://avatars.githubusercontent.com/u/131590...              ...
# 13  https://avatars.githubusercontent.com/u/106470...              ...
# 14  https://avatars.githubusercontent.com/u/345224...              ...
# 15  https://avatars.githubusercontent.com/u/447616...              ...
# 16  https://avatars.githubusercontent.com/u/116642...              ...
# 17  https://avatars.githubusercontent.com/u/151138...              ...
# 18  https://avatars.githubusercontent.com/u/31669?v=4              ...
# 19  https://avatars.githubusercontent.com/u/180782...              ...
# 20  https://avatars.githubusercontent.com/u/535194...              ...
# 21  https://avatars.githubusercontent.com/u/233368...              ...
# 22  https://avatars.githubusercontent.com/u/151138...              ...
# 23  https://avatars.githubusercontent.com/u/323679...              ...
# 24  https://avatars.githubusercontent.com/u/575878...              ...
# 25  https://avatars.githubusercontent.com/u/321116...              ...
# 26  https://avatars.githubusercontent.com/u/321116...              ...
# 27  https://avatars.githubusercontent.com/u/904003...              ...
# 28  https://avatars.githubusercontent.com/u/301966...              ...
# 29  https://avatars.githubusercontent.com/u/575878...              ...
#
#                                         following_url  \
# 0   https://api.github.com/users/NickCrews/followi...
# 1   https://api.github.com/users/LucasG0/following...
# 2   https://api.github.com/users/eromoe/following{...
# 3   https://api.github.com/users/datapythonista/fo...
# 4   https://api.github.com/users/lorentzbao/follow...
# 5   https://api.github.com/users/ehariri/following...
# 6   https://api.github.com/users/mosc9575/followin...
# 7   https://api.github.com/users/shyamsantoki/foll...
# 8   https://api.github.com/users/twoertwein/follow...
# 9   https://api.github.com/users/vruthik/following...
# 10  https://api.github.com/users/charlesbluca/foll...
# 11  https://api.github.com/users/andjhall/followin...
# 12  https://api.github.com/users/simonjayhawkins/f...
# 13  https://api.github.com/users/mroeschke/followi...
# 14  https://api.github.com/users/ma3da/following{/...
# 15  https://api.github.com/users/kwhkim/following{...
# 16  https://api.github.com/users/galipremsagar/fol...
# 17  https://api.github.com/users/Dr-Irv/following{...
# 18  https://api.github.com/users/Moisan/following{...
# 19  https://api.github.com/users/maalgorium/follow...
# 20  https://api.github.com/users/andreareina/follo...
# 21  https://api.github.com/users/douglas-raillard-...
# 22  https://api.github.com/users/Dr-Irv/following{...
# 23  https://api.github.com/users/smarie/following{...
# 24  https://api.github.com/users/gwerbin/following...
# 25  https://api.github.com/users/RogerThomas/follo...
# 26  https://api.github.com/users/RogerThomas/follo...
# 27  https://api.github.com/users/cmjcharlton/follo...
# 28  https://api.github.com/users/jakirkham/followi...
# 29  https://api.github.com/users/gwerbin/following...
#
#                                             gists_url  \
# 0   https://api.github.com/users/NickCrews/gists{/...
# 1   https://api.github.com/users/LucasG0/gists{/gi...
# 2   https://api.github.com/users/eromoe/gists{/gis...
# 3   https://api.github.com/users/datapythonista/gi...
# 4   https://api.github.com/users/lorentzbao/gists{...
# 5   https://api.github.com/users/ehariri/gists{/gi...
# 6   https://api.github.com/users/mosc9575/gists{/g...
# 7   https://api.github.com/users/shyamsantoki/gist...
# 8   https://api.github.com/users/twoertwein/gists{...
# 9   https://api.github.com/users/vruthik/gists{/gi...
# 10  https://api.github.com/users/charlesbluca/gist...
# 11  https://api.github.com/users/andjhall/gists{/g...
# 12  https://api.github.com/users/simonjayhawkins/g...
# 13  https://api.github.com/users/mroeschke/gists{/...
# 14  https://api.github.com/users/ma3da/gists{/gist...
# 15  https://api.github.com/users/kwhkim/gists{/gis...
# 16  https://api.github.com/users/galipremsagar/gis...
# 17  https://api.github.com/users/Dr-Irv/gists{/gis...
# 18  https://api.github.com/users/Moisan/gists{/gis...
# 19  https://api.github.com/users/maalgorium/gists{...
# 20  https://api.github.com/users/andreareina/gists...
# 21  https://api.github.com/users/douglas-raillard-...
# 22  https://api.github.com/users/Dr-Irv/gists{/gis...
# 23  https://api.github.com/users/smarie/gists{/gis...
# 24  https://api.github.com/users/gwerbin/gists{/gi...
# 25  https://api.github.com/users/RogerThomas/gists...
# 26  https://api.github.com/users/RogerThomas/gists...
# 27  https://api.github.com/users/cmjcharlton/gists...
# 28  https://api.github.com/users/jakirkham/gists{/...
# 29  https://api.github.com/users/gwerbin/gists{/gi...
#
#                                           starred_url  \
# 0   https://api.github.com/users/NickCrews/starred...
# 1   https://api.github.com/users/LucasG0/starred{/...
# 2   https://api.github.com/users/eromoe/starred{/o...
# 3   https://api.github.com/users/datapythonista/st...
# 4   https://api.github.com/users/lorentzbao/starre...
# 5   https://api.github.com/users/ehariri/starred{/...
# 6   https://api.github.com/users/mosc9575/starred{...
# 7   https://api.github.com/users/shyamsantoki/star...
# 8   https://api.github.com/users/twoertwein/starre...
# 9   https://api.github.com/users/vruthik/starred{/...
# 10  https://api.github.com/users/charlesbluca/star...
# 11  https://api.github.com/users/andjhall/starred{...
# 12  https://api.github.com/users/simonjayhawkins/s...
# 13  https://api.github.com/users/mroeschke/starred...
# 14  https://api.github.com/users/ma3da/starred{/ow...
# 15  https://api.github.com/users/kwhkim/starred{/o...
# 16  https://api.github.com/users/galipremsagar/sta...
# 17  https://api.github.com/users/Dr-Irv/starred{/o...
# 18  https://api.github.com/users/Moisan/starred{/o...
# 19  https://api.github.com/users/maalgorium/starre...
# 20  https://api.github.com/users/andreareina/starr...
# 21  https://api.github.com/users/douglas-raillard-...
# 22  https://api.github.com/users/Dr-Irv/starred{/o...
# 23  https://api.github.com/users/smarie/starred{/o...
# 24  https://api.github.com/users/gwerbin/starred{/...
# 25  https://api.github.com/users/RogerThomas/starr...
# 26  https://api.github.com/users/RogerThomas/starr...
# 27  https://api.github.com/users/cmjcharlton/starr...
# 28  https://api.github.com/users/jakirkham/starred...
# 29  https://api.github.com/users/gwerbin/starred{/...
#
#                                     subscriptions_url  \
# 0   https://api.github.com/users/NickCrews/subscri...
# 1   https://api.github.com/users/LucasG0/subscript...
# 2   https://api.github.com/users/eromoe/subscriptions
# 3   https://api.github.com/users/datapythonista/su...
# 4   https://api.github.com/users/lorentzbao/subscr...
# 5   https://api.github.com/users/ehariri/subscript...
# 6   https://api.github.com/users/mosc9575/subscrip...
# 7   https://api.github.com/users/shyamsantoki/subs...
# 8   https://api.github.com/users/twoertwein/subscr...
# 9   https://api.github.com/users/vruthik/subscript...
# 10  https://api.github.com/users/charlesbluca/subs...
# 11  https://api.github.com/users/andjhall/subscrip...
# 12  https://api.github.com/users/simonjayhawkins/s...
# 13  https://api.github.com/users/mroeschke/subscri...
# 14   https://api.github.com/users/ma3da/subscriptions
# 15  https://api.github.com/users/kwhkim/subscriptions
# 16  https://api.github.com/users/galipremsagar/sub...
# 17  https://api.github.com/users/Dr-Irv/subscriptions
# 18  https://api.github.com/users/Moisan/subscriptions
# 19  https://api.github.com/users/maalgorium/subscr...
# 20  https://api.github.com/users/andreareina/subsc...
# 21  https://api.github.com/users/douglas-raillard-...
# 22  https://api.github.com/users/Dr-Irv/subscriptions
# 23  https://api.github.com/users/smarie/subscriptions
# 24  https://api.github.com/users/gwerbin/subscript...
# 25  https://api.github.com/users/RogerThomas/subsc...
# 26  https://api.github.com/users/RogerThomas/subsc...
# 27  https://api.github.com/users/cmjcharlton/subsc...
# 28  https://api.github.com/users/jakirkham/subscri...
# 29  https://api.github.com/users/gwerbin/subscript...
#
#                                     organizations_url  \
# 0         https://api.github.com/users/NickCrews/orgs
# 1           https://api.github.com/users/LucasG0/orgs
# 2            https://api.github.com/users/eromoe/orgs
# 3    https://api.github.com/users/datapythonista/orgs
# 4        https://api.github.com/users/lorentzbao/orgs
# 5           https://api.github.com/users/ehariri/orgs
# 6          https://api.github.com/users/mosc9575/orgs
# 7      https://api.github.com/users/shyamsantoki/orgs
# 8        https://api.github.com/users/twoertwein/orgs
# 9           https://api.github.com/users/vruthik/orgs
# 10     https://api.github.com/users/charlesbluca/orgs
# 11         https://api.github.com/users/andjhall/orgs
# 12  https://api.github.com/users/simonjayhawkins/orgs
# 13        https://api.github.com/users/mroeschke/orgs
# 14            https://api.github.com/users/ma3da/orgs
# 15           https://api.github.com/users/kwhkim/orgs
# 16    https://api.github.com/users/galipremsagar/orgs
# 17           https://api.github.com/users/Dr-Irv/orgs
# 18           https://api.github.com/users/Moisan/orgs
# 19       https://api.github.com/users/maalgorium/orgs
# 20      https://api.github.com/users/andreareina/orgs
# 21  https://api.github.com/users/douglas-raillard-...
# 22           https://api.github.com/users/Dr-Irv/orgs
# 23           https://api.github.com/users/smarie/orgs
# 24          https://api.github.com/users/gwerbin/orgs
# 25      https://api.github.com/users/RogerThomas/orgs
# 26      https://api.github.com/users/RogerThomas/orgs
# 27      https://api.github.com/users/cmjcharlton/orgs
# 28        https://api.github.com/users/jakirkham/orgs
# 29          https://api.github.com/users/gwerbin/orgs
#
#                                             repos_url  \
# 0        https://api.github.com/users/NickCrews/repos
# 1          https://api.github.com/users/LucasG0/repos
# 2           https://api.github.com/users/eromoe/repos
# 3   https://api.github.com/users/datapythonista/repos
# 4       https://api.github.com/users/lorentzbao/repos
# 5          https://api.github.com/users/ehariri/repos
# 6         https://api.github.com/users/mosc9575/repos
# 7     https://api.github.com/users/shyamsantoki/repos
# 8       https://api.github.com/users/twoertwein/repos
# 9          https://api.github.com/users/vruthik/repos
# 10    https://api.github.com/users/charlesbluca/repos
# 11        https://api.github.com/users/andjhall/repos
# 12  https://api.github.com/users/simonjayhawkins/r...
# 13       https://api.github.com/users/mroeschke/repos
# 14           https://api.github.com/users/ma3da/repos
# 15          https://api.github.com/users/kwhkim/repos
# 16   https://api.github.com/users/galipremsagar/repos
# 17          https://api.github.com/users/Dr-Irv/repos
# 18          https://api.github.com/users/Moisan/repos
# 19      https://api.github.com/users/maalgorium/repos
# 20     https://api.github.com/users/andreareina/repos
# 21  https://api.github.com/users/douglas-raillard-...
# 22          https://api.github.com/users/Dr-Irv/repos
# 23          https://api.github.com/users/smarie/repos
# 24         https://api.github.com/users/gwerbin/repos
# 25     https://api.github.com/users/RogerThomas/repos
# 26     https://api.github.com/users/RogerThomas/repos
# 27     https://api.github.com/users/cmjcharlton/repos
# 28       https://api.github.com/users/jakirkham/repos
# 29         https://api.github.com/users/gwerbin/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/NickCrews/events{...
# 1   https://api.github.com/users/LucasG0/events{/p...
# 2   https://api.github.com/users/eromoe/events{/pr...
# 3   https://api.github.com/users/datapythonista/ev...
# 4   https://api.github.com/users/lorentzbao/events...
# 5   https://api.github.com/users/ehariri/events{/p...
# 6   https://api.github.com/users/mosc9575/events{/...
# 7   https://api.github.com/users/shyamsantoki/even...
# 8   https://api.github.com/users/twoertwein/events...
# 9   https://api.github.com/users/vruthik/events{/p...
# 10  https://api.github.com/users/charlesbluca/even...
# 11  https://api.github.com/users/andjhall/events{/...
# 12  https://api.github.com/users/simonjayhawkins/e...
# 13  https://api.github.com/users/mroeschke/events{...
# 14  https://api.github.com/users/ma3da/events{/pri...
# 15  https://api.github.com/users/kwhkim/events{/pr...
# 16  https://api.github.com/users/galipremsagar/eve...
# 17  https://api.github.com/users/Dr-Irv/events{/pr...
# 18  https://api.github.com/users/Moisan/events{/pr...
# 19  https://api.github.com/users/maalgorium/events...
# 20  https://api.github.com/users/andreareina/event...
# 21  https://api.github.com/users/douglas-raillard-...
# 22  https://api.github.com/users/Dr-Irv/events{/pr...
# 23  https://api.github.com/users/smarie/events{/pr...
# 24  https://api.github.com/users/gwerbin/events{/p...
# 25  https://api.github.com/users/RogerThomas/event...
# 26  https://api.github.com/users/RogerThomas/event...
# 27  https://api.github.com/users/cmjcharlton/event...
# 28  https://api.github.com/users/jakirkham/events{...
# 29  https://api.github.com/users/gwerbin/events{/p...
#
#                                   received_events_url  type site_admin
# 0   https://api.github.com/users/NickCrews/receive...  User      False
# 1   https://api.github.com/users/LucasG0/received_...  User      False
# 2   https://api.github.com/users/eromoe/received_e...  User      False
# 3   https://api.github.com/users/datapythonista/re...  User      False
# 4   https://api.github.com/users/lorentzbao/receiv...  User      False
# 5   https://api.github.com/users/ehariri/received_...  User      False
# 6   https://api.github.com/users/mosc9575/received...  User      False
# 7   https://api.github.com/users/shyamsantoki/rece...  User      False
# 8   https://api.github.com/users/twoertwein/receiv...  User      False
# 9   https://api.github.com/users/vruthik/received_...  User      False
# 10  https://api.github.com/users/charlesbluca/rece...  User      False
# 11  https://api.github.com/users/andjhall/received...  User      False
# 12  https://api.github.com/users/simonjayhawkins/r...  User      False
# 13  https://api.github.com/users/mroeschke/receive...  User      False
# 14  https://api.github.com/users/ma3da/received_ev...  User      False
# 15  https://api.github.com/users/kwhkim/received_e...  User      False
# 16  https://api.github.com/users/galipremsagar/rec...  User      False
# 17  https://api.github.com/users/Dr-Irv/received_e...  User      False
# 18  https://api.github.com/users/Moisan/received_e...  User      False
# 19  https://api.github.com/users/maalgorium/receiv...  User      False
# 20  https://api.github.com/users/andreareina/recei...  User      False
# 21  https://api.github.com/users/douglas-raillard-...  User      False
# 22  https://api.github.com/users/Dr-Irv/received_e...  User      False
# 23  https://api.github.com/users/smarie/received_e...  User      False
# 24  https://api.github.com/users/gwerbin/received_...  User      False
# 25  https://api.github.com/users/RogerThomas/recei...  User      False
# 26  https://api.github.com/users/RogerThomas/recei...  User      False
# 27  https://api.github.com/users/cmjcharlton/recei...  User      False
# 28  https://api.github.com/users/jakirkham/receive...  User      False
# 29  https://api.github.com/users/gwerbin/received_...  User      False
#
# [30 rows x 23 columns]
