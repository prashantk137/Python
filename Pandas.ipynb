# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1E4D-DCE3
#
#  Directory of C:\Users\PRASHANT KUMAR
#
# 16-04-2022  12:50    <DIR>          .
# 16-01-2022  13:18    <DIR>          ..
# 15-12-2019  12:13    <DIR>          .anaconda
# 14-02-2020  11:35    <DIR>          .android
# 17-01-2020  11:04    <DIR>          .AndroidStudio3.5
# 21-07-2020  17:20               145 .appletviewer
# 25-03-2022  10:52             1,010 .bash_history
# 29-06-2021  14:36    <DIR>          .cache
# 25-02-2022  09:33    <DIR>          .conda
# 15-10-2020  13:05                43 .condarc
# 08-02-2020  15:55    <DIR>          .config
# 28-11-2021  13:34    <DIR>          .continuum
# 14-06-2020  13:49    <DIR>          .dotnet
# 11-03-2020  18:33    <DIR>          .eclipse
# 17-01-2020  11:55                16 .emulator_console_auth_token
# 25-03-2022  09:44               214 .gitconfig
# 25-03-2022  09:04            12,288 .gitconfig.swp
# 17-01-2020  11:55    <DIR>          .gradle
# ...

# %%
pd.read_csv('sample_test.csv')
# Out:
#        Name                emailid    address  pincode       sirname
# 0  prashant  prasantk065@gmail.com  begusarai   851130         kumar
# 1     krish        krish@gmail.com  bengalore   560085          naik
# 2   ineuron      ineuron@gmail.com  bengalore   560085  intelligence
# 3    pandas       pandas@gmail.com    chennai   230045      tutorial

# %%
pd.read_csv('D:\iNeuron\ohana-api-master\data\sample-csv\locations.csv')
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
df=pd.read_csv('D:\iNeuron\ohana-api-master\data\sample-csv\contacts.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\PRASHA~1\AppData\Local\Temp/ipykernel_13108/3835792105.py in <module>
# ----> 1 df=pd.read_csv('D:\iNeuron\ohana-api-master\data\sample-csv\contacts.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv('D:\iNeuron\ohana-api-master\data\sample-csv\contacts.csv',header=None)
# Out:
#      0     1    2     3                        4  \
# 0    1   1.0  NaN   NaN            Susan Houston
# 1    2   1.0  NaN   NaN       Christina Gonzalez
# 2    3   2.0  NaN   NaN             Brenda Brown
# 3    4   3.0  NaN   NaN       Howard Lader, LCSW
# 4    5   4.0  NaN   NaN       Kimberly Pesavento
# 5    6   5.0  NaN   NaN                Joe Bloom
# 6    7   6.0  NaN   NaN              Peter Olson
# 7    8   6.0  NaN   NaN             Bart Charlow
# 8    9   7.0  NaN   NaN             Bart Charlow
# 9   10   7.0  NaN   NaN             Barbara Kalt
# 10  11   8.0  NaN   NaN  Marilyn Baker-Venturini
# 11  12   8.0  NaN   NaN       Graciela Hernandez
# 12  13   8.0  NaN   NaN            Julie Avelino
# 13  14   9.0  NaN   NaN              Dave Genesy
# 14  15   9.0  NaN   NaN             Maria Kramer
# 15  16  10.0  NaN   NaN              Dave Genesy
# 16  17  10.0  NaN   NaN             Maria Kramer
# 17  18  11.0  NaN   NaN              Dave Genesy
# ...

# %%
pd.read_csv('D:\iNeuron\ohana-api-master\data\sample-csv\contacts.csv',names=['A','B','C','D','E','F','G','H'])
# Out:
#      A     B    C     D                        E  \
# 0    1   1.0  NaN   NaN            Susan Houston
# 1    2   1.0  NaN   NaN       Christina Gonzalez
# 2    3   2.0  NaN   NaN             Brenda Brown
# 3    4   3.0  NaN   NaN       Howard Lader, LCSW
# 4    5   4.0  NaN   NaN       Kimberly Pesavento
# 5    6   5.0  NaN   NaN                Joe Bloom
# 6    7   6.0  NaN   NaN              Peter Olson
# 7    8   6.0  NaN   NaN             Bart Charlow
# 8    9   7.0  NaN   NaN             Bart Charlow
# 9   10   7.0  NaN   NaN             Barbara Kalt
# 10  11   8.0  NaN   NaN  Marilyn Baker-Venturini
# 11  12   8.0  NaN   NaN       Graciela Hernandez
# 12  13   8.0  NaN   NaN            Julie Avelino
# 13  14   9.0  NaN   NaN              Dave Genesy
# 14  15   9.0  NaN   NaN             Maria Kramer
# 15  16  10.0  NaN   NaN              Dave Genesy
# 16  17  10.0  NaN   NaN             Maria Kramer
# 17  18  11.0  NaN   NaN              Dave Genesy
# ...

# %%
pd.read_csv('D:\iNeuron\ohana-api-master\data\sample-csv\contacts.csv',names=['A','B','C','D','E'])
# Out:
#                 A                        B  \
# 1  1.0  NaN   NaN            Susan Houston
# 2  1.0  NaN   NaN       Christina Gonzalez
# 3  2.0  NaN   NaN             Brenda Brown
# 4  3.0  NaN   NaN       Howard Lader, LCSW
# 5  4.0  NaN   NaN       Kimberly Pesavento
# 6  5.0  NaN   NaN                Joe Bloom
# 7  6.0  NaN   NaN              Peter Olson
# 8  6.0  NaN   NaN             Bart Charlow
# 9  7.0  NaN   NaN             Bart Charlow
# 10 7.0  NaN   NaN             Barbara Kalt
# 11 8.0  NaN   NaN  Marilyn Baker-Venturini
# 12 8.0  NaN   NaN       Graciela Hernandez
# 13 8.0  NaN   NaN            Julie Avelino
# 14 9.0  NaN   NaN              Dave Genesy
# 15 9.0  NaN   NaN             Maria Kramer
# 16 10.0 NaN   NaN              Dave Genesy
# 17 10.0 NaN   NaN             Maria Kramer
# 18 11.0 NaN   NaN              Dave Genesy
# 19 11.0 NaN   NaN          Elizabeth Meeks
# 20 12.0 NaN   NaN             Kathy Endaya
# 21 13.0 NaN   NaN              Dave Genesy
# ...

# %%
pd.read_csv('sample_test.csv')
# Out:
#        Name                emailid    address  pincode       sirname
# 0  prashant  prasantk065@gmail.com  begusarai   851130         kumar
# 1     krish        krish@gmail.com  bengalore   560085          naik
# 2   ineuron      ineuron@gmail.com  bengalore   560085  intelligence
# 3    pandas       pandas@gmail.com    chennai   230045      tutorial

# %%
pd.read_csv('sample_test.csv')
# Out:
#                 Name@emailid@address@pincode@sirname
# 0  prashant@prasantk065@gmail.com@begusarai@85113...
# 1        krish@krish@gmail.com@bengalore@560085@naik
# 2  ineuron@ineuron@gmail.com@bengalore@560085@int...
# 3    pandas@pandas@gmail.com@chennai@230045@tutorial

# %%
pd.read_csv('sample_test.csv',sep='@')
# Out:
#                  Name    emailid    address  pincode       sirname
# prashant  prasantk065  gmail.com  begusarai   851130         kumar
# krish           krish  gmail.com  bengalore   560085          naik
# ineuron       ineuron  gmail.com  bengalore   560085  intelligence
# pandas         pandas  gmail.com    chennai   230045      tutorial

# %%
pd.read_csv('sample_test.csv')
# Out:
#                 Name|emailid|address|pincode|sirname
# 0  prashant|prasantk065|gmail.com|begusarai|85113...
# 1        krish|krish|gmail.com|bengalore|560085|naik
# 2  ineuron|ineuron|gmail.com|bengalore|560085|int...
# 3    pandas|pandas|gmail.com|chennai|230045|tutorial

# %%
df=pd.read_csv('sample_test.csv',sep='|')

# %%
df
# Out:
#        Name                emailid    address  pincode       sirname
# 0  prashant  prasantk065@gmail.com  begusarai   851130         kumar
# 1     krish        krish@gmail.com  bengalore   560085          naik
# 2   ineuron      ineuron@gmail.com  bengalore   560085  intelligence
# 3    pandas       pandas@gmail.com    chennai   230045      tutorial

# %%
pd.read_csv('sample_test.csv',sep='|',skiprows=[1,3])
# Out:
#      Name           emailid    address  pincode   sirname
# 0   krish   krish@gmail.com  bengalore   560085      naik
# 1  pandas  pandas@gmail.com    chennai   230045  tutorial

# %%
df=pd.read_csv('D:\iNeuron\ohana-api-master\data\sample-csv\services.csv')

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# ...

# %%
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df.tail(2)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# 22  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...        None
#
#                     email  ...  \
# 21  passports@example.org  ...
# 22                    NaN  ...
#
#                               interpretation_services  \
# 21  We offer 3-way interpretation services over th...
# ...

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df['email']
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21    passports@example.org
# 22                      NaN
# Name: email, dtype: object

# %%
a=df['name']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df["name",'email']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('name', 'email')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[["name",'email','location_id']]
# Out:
#                                     name                  email  location_id
# 0        Fair Oaks Adult Activity Center                    NaN            1
# 1       Second Career Employment Program                    NaN            2
# 2                 Senior Peer Counseling                    NaN            3
# 3               Family Visitation Center                    NaN            4
# 4      Economic Self-Sufficiency Program                    NaN            5
# 5   Little House Recreational Activities                    NaN            6
# 6       Rosener House Adult Day Services                    NaN            7
# 7         Meals on Wheels - South County                    NaN            8
# 8                       Fair Oaks Branch                    NaN            9
# 9                           Main Library                    NaN           10
# 10                       Schaberg Branch                    NaN           11
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[["name"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["name"])
# Out:
# pandas.core.series.Series

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1E4D-DCE3
#
#  Directory of C:\Users\PRASHANT KUMAR
#
# 16-04-2022  14:30    <DIR>          .
# 16-01-2022  13:18    <DIR>          ..
# 15-12-2019  12:13    <DIR>          .anaconda
# 14-02-2020  11:35    <DIR>          .android
# 17-01-2020  11:04    <DIR>          .AndroidStudio3.5
# 21-07-2020  17:20               145 .appletviewer
# 25-03-2022  10:52             1,010 .bash_history
# 29-06-2021  14:36    <DIR>          .cache
# 25-02-2022  09:33    <DIR>          .conda
# 15-10-2020  13:05                43 .condarc
# 08-02-2020  15:55    <DIR>          .config
# 28-11-2021  13:34    <DIR>          .continuum
# 14-06-2020  13:49    <DIR>          .dotnet
# 11-03-2020  18:33    <DIR>          .eclipse
# 17-01-2020  11:55                16 .emulator_console_auth_token
# 25-03-2022  09:44               214 .gitconfig
# 25-03-2022  09:04            12,288 .gitconfig.swp
# 17-01-2020  11:55    <DIR>          .gradle
# ...

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx')
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx',sheet_name="Allocations")
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
df=pd.read_excel('LUSID Excel - Manage Orders.xlsx')

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18'],
#       dtype='object')

# %%
df=pd.ExcelFile('LUSID Excel - Manage Orders.xlsx')

# %%
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
for i in df.sheet_names:
    pd.read_excel('LUSID Excel - Manage Orders.xlsx',sheet_name=i)

# %%
pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# C:\Users\PRASHA~1\AppData\Local\Temp/ipykernel_5816/2188339314.py in <module>
# ----> 1 pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
